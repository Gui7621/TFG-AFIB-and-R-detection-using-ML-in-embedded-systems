# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import wfdb
import ast

# %%
def load_raw_data(df, sampling_rate, path):
    '''
    função para carregar os dados originais
    '''
    if sampling_rate == 100:
        data = [wfdb.rdsamp(path+f) for f in df.filename_lr]
    else:
        data = [wfdb.rdsamp(path+f) for f in df.filename_hr]
    data = np.array([signal for signal, meta in data])
    return data

# %%
path = ''
sampling_rate=100

# %%
Y = pd.read_csv(path+'ptbxl_database.csv', index_col='ecg_id')
Y.scp_codes = Y.scp_codes.apply(lambda x: ast.literal_eval(x))

# %%
X = load_raw_data(Y, sampling_rate, path)

# %%
agg_df = pd.read_csv(path+'scp_statements.csv', index_col=0)
agg_df = agg_df[agg_df.rhythm == 1]

# %%
agg_df.shape
# Out:
# (12, 12)

# %%
agg_df
# Out:
#                                              description  diagnostic  form  \
# SR                                          sinus rhythm         NaN   NaN
# AFIB                                 atrial fibrillation         NaN   NaN
# STACH                                  sinus tachycardia         NaN   NaN
# SARRH                                   sinus arrhythmia         NaN   NaN
# SBRAD                                  sinus bradycardia         NaN   NaN
# PACE             normal functioning artificial pacemaker         NaN   NaN
# SVARR                        supraventricular arrhythmia         NaN   NaN
# BIGU   bigeminal pattern (unknown origin, SV or Ventr...         NaN   NaN
# AFLT                                      atrial flutter         NaN   NaN
# SVTAC                       supraventricular tachycardia         NaN   NaN
# PSVT             paroxysmal supraventricular tachycardia         NaN   NaN
# TRIGU  trigeminal pattern (unknown origin, SV or Vent...         NaN   NaN
#
#        rhythm diagnostic_class diagnostic_subclass  \
# SR        1.0              NaN                 NaN
# AFIB      1.0              NaN                 NaN
# STACH     1.0              NaN                 NaN
# SARRH     1.0              NaN                 NaN
# SBRAD     1.0              NaN                 NaN
# PACE      1.0              NaN                 NaN
# SVARR     1.0              NaN                 NaN
# BIGU      1.0              NaN                 NaN
# AFLT      1.0              NaN                 NaN
# SVTAC     1.0              NaN                 NaN
# PSVT      1.0              NaN                 NaN
# TRIGU     1.0              NaN                 NaN
#
#                                       Statement Category  \
# SR     Statements related to impulse formation (abnor...
# AFIB   Statements related to impulse formation (abnor...
# STACH  Statements related to impulse formation (abnor...
# SARRH  Statements related to impulse formation (abnor...
# SBRAD  Statements related to impulse formation (abnor...
# PACE              Pacemaker types and pacemaker function
# SVARR  Statements related to impulse formation (abnor...
# BIGU   Statements related to ectopic rhythm abnormali...
# AFLT   Statements related to impulse formation (abnor...
# SVTAC  Statements related to impulse formation (abnor...
# PSVT   Statements related to impulse formation (abnor...
# TRIGU  Statements related to ectopic rhythm abnormali...
#
#                            SCP-ECG Statement Description  AHA code  \
# SR                                          sinus rhythm      20.0
# AFIB                                 atrial fibrillation      50.0
# STACH                                  sinus tachycardia      21.0
# SARRH                                   sinus arrhythmia      23.0
# SBRAD                                  sinus bradycardia      22.0
# PACE             normal functioning artificial pacemaker       NaN
# SVARR                        supraventricular arrhythmia       NaN
# BIGU   bigeminal pattern (unknown origin, SV or Ventr...       NaN
# AFLT                                      atrial flutter      51.0
# SVTAC                       supraventricular tachycardia      55.0
# PSVT             paroxysmal supraventricular tachycardia       NaN
# TRIGU  trigeminal pattern (unknown origin, SV or Vent...       NaN
#
#                        aECG REFID CDISC Code DICOM Code
# SR          MDC_ECG_RHY_SINUS_RHY        NaN        NaN
# AFIB          MDC_ECG_RHY_ATR_FIB        NaN   D3-31520
# STACH     MDC_ECG_RHY_SINUS_TACHY        NaN        NaN
# SARRH     MDC_ECG_RHY_SINUS_ARRHY        NaN        NaN
# SBRAD     MDC_ECG_RHY_SINUS_BRADY        NaN        NaN
# PACE                          NaN        NaN        NaN
# SVARR                         NaN        NaN        NaN
# BIGU                          NaN        NaN        NaN
# AFLT         MDC_ECG_RHY_ATR_FLUT        NaN        NaN
# SVTAC        MDC_ECG_RHY_SV_TACHY        NaN   D3-31290
# PSVT   MDC_ECG_RHY_SV_TACHY_PAROX        NaN        NaN
# TRIGU                         NaN        NaN        NaN

# %%
agg_df['rhythm_statement'] = agg_df.index

# %%
agg_df
# Out:
#                                              description  diagnostic  form  \
# SR                                          sinus rhythm         NaN   NaN
# AFIB                                 atrial fibrillation         NaN   NaN
# STACH                                  sinus tachycardia         NaN   NaN
# SARRH                                   sinus arrhythmia         NaN   NaN
# SBRAD                                  sinus bradycardia         NaN   NaN
# PACE             normal functioning artificial pacemaker         NaN   NaN
# SVARR                        supraventricular arrhythmia         NaN   NaN
# BIGU   bigeminal pattern (unknown origin, SV or Ventr...         NaN   NaN
# AFLT                                      atrial flutter         NaN   NaN
# SVTAC                       supraventricular tachycardia         NaN   NaN
# PSVT             paroxysmal supraventricular tachycardia         NaN   NaN
# TRIGU  trigeminal pattern (unknown origin, SV or Vent...         NaN   NaN
#
#        rhythm diagnostic_class diagnostic_subclass  \
# SR        1.0              NaN                 NaN
# AFIB      1.0              NaN                 NaN
# STACH     1.0              NaN                 NaN
# SARRH     1.0              NaN                 NaN
# SBRAD     1.0              NaN                 NaN
# PACE      1.0              NaN                 NaN
# SVARR     1.0              NaN                 NaN
# BIGU      1.0              NaN                 NaN
# AFLT      1.0              NaN                 NaN
# SVTAC     1.0              NaN                 NaN
# PSVT      1.0              NaN                 NaN
# TRIGU     1.0              NaN                 NaN
#
#                                       Statement Category  \
# SR     Statements related to impulse formation (abnor...
# AFIB   Statements related to impulse formation (abnor...
# STACH  Statements related to impulse formation (abnor...
# SARRH  Statements related to impulse formation (abnor...
# SBRAD  Statements related to impulse formation (abnor...
# PACE              Pacemaker types and pacemaker function
# SVARR  Statements related to impulse formation (abnor...
# BIGU   Statements related to ectopic rhythm abnormali...
# AFLT   Statements related to impulse formation (abnor...
# SVTAC  Statements related to impulse formation (abnor...
# PSVT   Statements related to impulse formation (abnor...
# TRIGU  Statements related to ectopic rhythm abnormali...
#
#                            SCP-ECG Statement Description  AHA code  \
# SR                                          sinus rhythm      20.0
# AFIB                                 atrial fibrillation      50.0
# STACH                                  sinus tachycardia      21.0
# SARRH                                   sinus arrhythmia      23.0
# SBRAD                                  sinus bradycardia      22.0
# PACE             normal functioning artificial pacemaker       NaN
# SVARR                        supraventricular arrhythmia       NaN
# BIGU   bigeminal pattern (unknown origin, SV or Ventr...       NaN
# AFLT                                      atrial flutter      51.0
# SVTAC                       supraventricular tachycardia      55.0
# PSVT             paroxysmal supraventricular tachycardia       NaN
# TRIGU  trigeminal pattern (unknown origin, SV or Vent...       NaN
#
#                        aECG REFID CDISC Code DICOM Code rhythm_statement
# SR          MDC_ECG_RHY_SINUS_RHY        NaN        NaN               SR
# AFIB          MDC_ECG_RHY_ATR_FIB        NaN   D3-31520             AFIB
# STACH     MDC_ECG_RHY_SINUS_TACHY        NaN        NaN            STACH
# SARRH     MDC_ECG_RHY_SINUS_ARRHY        NaN        NaN            SARRH
# SBRAD     MDC_ECG_RHY_SINUS_BRADY        NaN        NaN            SBRAD
# PACE                          NaN        NaN        NaN             PACE
# SVARR                         NaN        NaN        NaN            SVARR
# BIGU                          NaN        NaN        NaN             BIGU
# AFLT         MDC_ECG_RHY_ATR_FLUT        NaN        NaN             AFLT
# SVTAC        MDC_ECG_RHY_SV_TACHY        NaN   D3-31290            SVTAC
# PSVT   MDC_ECG_RHY_SV_TACHY_PAROX        NaN        NaN             PSVT
# TRIGU                         NaN        NaN        NaN            TRIGU

# %%
def aggregate_rhythm(y_dic):
    tmp = []
    for key in y_dic.keys():
        if key in agg_df.index:
            tmp.append(agg_df.loc[key].rhythm_statement)
    return list(set(tmp))

# %%
YI = Y.copy()

# %%
YI.head()
# Out:
#         patient_id   age  sex  height  weight  nurse  site     device  \
# ecg_id
# 1          15709.0  56.0    1     NaN    63.0    2.0   0.0  CS-12   E
# 2          13243.0  19.0    0     NaN    70.0    2.0   0.0  CS-12   E
# 3          20372.0  37.0    1     NaN    69.0    2.0   0.0  CS-12   E
# 4          17014.0  24.0    0     NaN    82.0    2.0   0.0  CS-12   E
# 5          17448.0  19.0    1     NaN    70.0    2.0   0.0  CS-12   E
#
#              recording_date                                  report  ...  \
# ecg_id                                                               ...
# 1       1984-11-09 09:17:34  sinusrhythmus periphere niederspannung  ...
# 2       1984-11-14 12:55:37     sinusbradykardie sonst normales ekg  ...
# 3       1984-11-15 12:49:10              sinusrhythmus normales ekg  ...
# 4       1984-11-15 13:44:57              sinusrhythmus normales ekg  ...
# 5       1984-11-17 10:43:15              sinusrhythmus normales ekg  ...
#
#        validated_by_human  baseline_drift static_noise burst_noise  \
# ecg_id
# 1                    True             NaN    , I-V1,           NaN
# 2                    True             NaN          NaN         NaN
# 3                    True             NaN          NaN         NaN
# 4                    True    , II,III,AVF          NaN         NaN
# 5                    True   , III,AVR,AVF          NaN         NaN
#
#         electrodes_problems  extra_beats  pacemaker  strat_fold  \
# ecg_id
# 1                       NaN          NaN        NaN           3
# 2                       NaN          NaN        NaN           2
# 3                       NaN          NaN        NaN           5
# 4                       NaN          NaN        NaN           3
# 5                       NaN          NaN        NaN           4
#
#                       filename_lr                filename_hr
# ecg_id
# 1       records100/00000/00001_lr  records500/00000/00001_hr
# 2       records100/00000/00002_lr  records500/00000/00002_hr
# 3       records100/00000/00003_lr  records500/00000/00003_hr
# 4       records100/00000/00004_lr  records500/00000/00004_hr
# 5       records100/00000/00005_lr  records500/00000/00005_hr
#
# [5 rows x 27 columns]

# %%
YI['scp_codes']
# Out:
# ecg_id
# 1                 {'NORM': 100.0, 'LVOLT': 0.0, 'SR': 0.0}
# 2                             {'NORM': 80.0, 'SBRAD': 0.0}
# 3                               {'NORM': 100.0, 'SR': 0.0}
# 4                               {'NORM': 100.0, 'SR': 0.0}
# 5                               {'NORM': 100.0, 'SR': 0.0}
#                                ...
# 21833    {'NDT': 100.0, 'PVC': 100.0, 'VCLVH': 0.0, 'ST...
# 21834             {'NORM': 100.0, 'ABQRS': 0.0, 'SR': 0.0}
# 21835                           {'ISCAS': 50.0, 'SR': 0.0}
# 21836                           {'NORM': 100.0, 'SR': 0.0}
# 21837                           {'NORM': 100.0, 'SR': 0.0}
# Name: scp_codes, Length: 21837, dtype: object

# %%
YI['heart_axis']
# Out:
# ecg_id
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# 5        NaN
#         ...
# 21833    LAD
# 21834    MID
# 21835    MID
# 21836    LAD
# 21837    MID
# Name: heart_axis, Length: 21837, dtype: object

# %%
YI['infarction_stadium1']
# Out:
# ecg_id
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# 5                   NaN
#               ...
# 21833               NaN
# 21834    Stadium II-III
# 21835               NaN
# 21836               NaN
# 21837               NaN
# Name: infarction_stadium1, Length: 21837, dtype: object

# %%
YI['infarction_stadium2']
# Out:
# ecg_id
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# 5        NaN
#         ...
# 21833    NaN
# 21834    NaN
# 21835    NaN
# 21836    NaN
# 21837    NaN
# Name: infarction_stadium2, Length: 21837, dtype: object

# %%
YI['validated_by']
# Out:
# ecg_id
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# 5        NaN
#         ...
# 21833    1.0
# 21834    1.0
# 21835    1.0
# 21836    1.0
# 21837    1.0
# Name: validated_by, Length: 21837, dtype: float64

# %%
YI['second_opinion']
# Out:
# ecg_id
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
#          ...
# 21833    False
# 21834    False
# 21835     True
# 21836    False
# 21837    False
# Name: second_opinion, Length: 21837, dtype: bool

# %%
YI['initial_autogenerated_report']
# Out:
# ecg_id
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
#          ...
# 21833     True
# 21834     True
# 21835     True
# 21836     True
# 21837     True
# Name: initial_autogenerated_report, Length: 21837, dtype: bool

# %%
YI['validated_by_human']
# Out:
# ecg_id
# 1        True
# 2        True
# 3        True
# 4        True
# 5        True
#          ...
# 21833    True
# 21834    True
# 21835    True
# 21836    True
# 21837    True
# Name: validated_by_human, Length: 21837, dtype: bool

# %%
YI['baseline_drift']
# Out:
# ecg_id
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4          , II,III,AVF
# 5         , III,AVR,AVF
#               ...
# 21833               NaN
# 21834               NaN
# 21835               NaN
# 21836               NaN
# 21837               NaN
# Name: baseline_drift, Length: 21837, dtype: object

# %%
YI['static_noise']
# Out:
# ecg_id
# 1          , I-V1,
# 2                NaN
# 3                NaN
# 4                NaN
# 5                NaN
#             ...
# 21833     , alles,
# 21834            NaN
# 21835     , I-AVR,
# 21836            NaN
# 21837     , I-AVL,
# Name: static_noise, Length: 21837, dtype: object

# %%
YI['burst_noise']
# Out:
# ecg_id
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# 5        NaN
#         ...
# 21833    NaN
# 21834    NaN
# 21835    NaN
# 21836    NaN
# 21837    NaN
# Name: burst_noise, Length: 21837, dtype: object

# %%
YI['electrodes_problems']
# Out:
# ecg_id
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# 5        NaN
#         ...
# 21833    NaN
# 21834    NaN
# 21835    NaN
# 21836    NaN
# 21837    NaN
# Name: electrodes_problems, Length: 21837, dtype: object

# %%
YI['extra_beats']
# Out:
# ecg_id
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
#          ...
# 21833     1ES
# 21834     NaN
# 21835     NaN
# 21836    SVES
# 21837     NaN
# Name: extra_beats, Length: 21837, dtype: object

# %%
YI['pacemaker']
# Out:
# ecg_id
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# 5        NaN
#         ...
# 21833    NaN
# 21834    NaN
# 21835    NaN
# 21836    NaN
# 21837    NaN
# Name: pacemaker, Length: 21837, dtype: object

# %%
YI['strat_fold']
# Out:
# ecg_id
# 1        3
# 2        2
# 3        5
# 4        3
# 5        4
#         ..
# 21833    7
# 21834    4
# 21835    2
# 21836    8
# 21837    9
# Name: strat_fold, Length: 21837, dtype: int64

# %%
YI['rhythm_class'] = YI.scp_codes.apply(aggregate_rhythm)

# %%
YI.shape
# Out:
# (21837, 28)

# %%
YI.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21837 entries, 1 to 21837
# Data columns (total 28 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   patient_id                    21837 non-null  float64
#  1   age                           21748 non-null  float64
#  2   sex                           21837 non-null  int64
#  3   height                        6983 non-null   float64
#  4   weight                        9429 non-null   float64
#  5   nurse                         20328 non-null  float64
#  6   site                          21819 non-null  float64
#  7   device                        21837 non-null  object
#  8   recording_date                21837 non-null  object
#  9   report                        21837 non-null  object
#  10  scp_codes                     21837 non-null  object
#  11  heart_axis                    13332 non-null  object
#  12  infarction_stadium1           5626 non-null   object
#  13  infarction_stadium2           103 non-null    object
#  14  validated_by                  12426 non-null  float64
#  15  second_opinion                21837 non-null  bool
#  16  initial_autogenerated_report  21837 non-null  bool
#  17  validated_by_human            21837 non-null  bool
#  18  baseline_drift                1607 non-null   object
#  19  static_noise                  3262 non-null   object
#  20  burst_noise                   613 non-null    object
#  21  electrodes_problems           30 non-null     object
#  22  extra_beats                   1954 non-null   object
#  23  pacemaker                     293 non-null    object
#  24  strat_fold                    21837 non-null  int64
#  25  filename_lr                   21837 non-null  object
#  26  filename_hr                   21837 non-null  object
#  27  rhythm_class                  21837 non-null  object
# dtypes: bool(3), float64(7), int64(2), object(16)
# memory usage: 4.4+ MB

# %%
YI['rhythm_class'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [SR]                 16721
# [AFIB]                1484
# [STACH]                805
# []                     771
# [SARRH]                765
# [SBRAD]                629
# [PACE]                 287
# [SVARR]                150
# [SR, BIGU]              37
# [AFLT]                  36
# [BIGU]                  22
# [AFIB, AFLT]            17
# [BIGU, STACH]           11
# [SR, TRIGU]             11
# [PSVT]                  10
# [SVTAC]                 10
# [PSVT, SVTAC]            8
# [BIGU, AFIB]             7
# [AFLT, SVTAC]            6
# [SR, AFLT]               5
# [STACH, AFLT]            5
# [AFLT, SVARR]            4
# [TRIGU]                  4
# [TRIGU, STACH]           4
# [PACE, AFIB]             4
# [PACE, SR]               3
# [SBRAD, SARRH]           3
# [SBRAD, BIGU]            3
# [PACE, SBRAD]            2
# [PSVT, SVARR]            2
# [SR, SARRH]              2
# [BIGU, SARRH]            2
# [SR, PSVT]               1
# [TRIGU, SVARR]           1
# [SR, SVTAC]              1
# [AFIB, PSVT]             1
# [AFIB, SVTAC]            1
# [STACH, PSVT]            1
# [SR, PSVT, SVTAC]        1
# Name: rhythm_class, dtype: int64

# %%
def get_diag(x_lst):
    if 'SR' in x_lst:
        diag = 'SR'
    elif 'AFIB' in x_lst:
        diag = 'AFIB'
    else:
        diag = 'OTHER'
    return diag

# %%
YI['rhythm_diag'] = YI.rhythm_class.apply(get_diag)

# %%
YI.head(10)
# Out:
#         patient_id   age  sex  height  weight  nurse  site     device  \
# ecg_id
# 1          15709.0  56.0    1     NaN    63.0    2.0   0.0  CS-12   E
# 2          13243.0  19.0    0     NaN    70.0    2.0   0.0  CS-12   E
# 3          20372.0  37.0    1     NaN    69.0    2.0   0.0  CS-12   E
# 4          17014.0  24.0    0     NaN    82.0    2.0   0.0  CS-12   E
# 5          17448.0  19.0    1     NaN    70.0    2.0   0.0  CS-12   E
# 6          19005.0  18.0    1     NaN    58.0    2.0   0.0  CS-12   E
# 7          16193.0  54.0    0     NaN    83.0    2.0   0.0  CS-12   E
# 8          11275.0  48.0    0     NaN    95.0    2.0   0.0  CS-12   E
# 9          18792.0  55.0    0     NaN    70.0    2.0   0.0  CS-12   E
# 10          9456.0  22.0    1     NaN    56.0    2.0   0.0  CS-12   E
#
#              recording_date  \
# ecg_id
# 1       1984-11-09 09:17:34
# 2       1984-11-14 12:55:37
# 3       1984-11-15 12:49:10
# 4       1984-11-15 13:44:57
# 5       1984-11-17 10:43:15
# 6       1984-11-28 13:32:13
# 7       1984-11-28 13:32:22
# 8       1984-12-01 14:49:52
# 9       1984-12-08 09:44:43
# 10      1984-12-12 14:12:46
#
#                                                    report  ... static_noise  \
# ecg_id                                                     ...
# 1                  sinusrhythmus periphere niederspannung  ...    , I-V1,
# 2                     sinusbradykardie sonst normales ekg  ...          NaN
# 3                              sinusrhythmus normales ekg  ...          NaN
# 4                              sinusrhythmus normales ekg  ...          NaN
# 5                              sinusrhythmus normales ekg  ...          NaN
# 6                              sinusrhythmus normales ekg  ...          NaN
# 7       sinusrhythmus linkstyp t abnormal, wahrscheinl...  ...          NaN
# 8       sinusrhythmus linkstyp qrs(t) abnormal    infe...  ...   , I-AVF,
# 9                              sinusrhythmus normales ekg  ...   , I-AVR,
# 10                             sinusrhythmus normales ekg  ...          NaN
#
#        burst_noise electrodes_problems extra_beats  pacemaker  strat_fold  \
# ecg_id
# 1              NaN                 NaN         NaN        NaN           3
# 2              NaN                 NaN         NaN        NaN           2
# 3              NaN                 NaN         NaN        NaN           5
# 4              NaN                 NaN         NaN        NaN           3
# 5              NaN                 NaN         NaN        NaN           4
# 6              NaN                 NaN         NaN        NaN           4
# 7              NaN                 NaN         NaN        NaN           7
# 8              NaN                 NaN         NaN        NaN           9
# 9              NaN                 NaN         NaN        NaN          10
# 10             NaN                 NaN         NaN        NaN           9
#
#                       filename_lr                filename_hr rhythm_class  \
# ecg_id
# 1       records100/00000/00001_lr  records500/00000/00001_hr         [SR]
# 2       records100/00000/00002_lr  records500/00000/00002_hr      [SBRAD]
# 3       records100/00000/00003_lr  records500/00000/00003_hr         [SR]
# 4       records100/00000/00004_lr  records500/00000/00004_hr         [SR]
# 5       records100/00000/00005_lr  records500/00000/00005_hr         [SR]
# 6       records100/00000/00006_lr  records500/00000/00006_hr         [SR]
# 7       records100/00000/00007_lr  records500/00000/00007_hr         [SR]
# 8       records100/00000/00008_lr  records500/00000/00008_hr         [SR]
# 9       records100/00000/00009_lr  records500/00000/00009_hr         [SR]
# 10      records100/00000/00010_lr  records500/00000/00010_hr         [SR]
#
#        rhythm_diag
# ecg_id
# 1               SR
# 2            OTHER
# 3               SR
# 4               SR
# 5               SR
# 6               SR
# 7               SR
# 8               SR
# 9               SR
# 10              SR
#
# [10 rows x 29 columns]

# %%
YI.rhythm_diag.value_counts()
# Out:
# SR       16782
# OTHER     3541
# AFIB      1514
# Name: rhythm_diag, dtype: int64

# %%
YI[YI.rhythm_diag == 'SR'].pacemaker.value_counts()
# Out:
# ja, nan          3
# PACE????, nan    2
# ja, pacemaker    1
# ?, nan           1
# Name: pacemaker, dtype: int64

# %%
YI[YI.rhythm_diag == 'AFIB'].pacemaker.value_counts()
# Out:
# ja, pacemaker    3
# Name: pacemaker, dtype: int64

# %%
YI[YI.rhythm_diag == 'SR'].electrodes_problems.value_counts()
# Out:
# V6                          5
# V4                          4
# Elektroden vertauscht???    1
# V3,V4-V6                    1
# Kontaktprobleme aVL ???     1
# V1                          1
# I???                        1
# V1???                       1
# V5                          1
# V5,V6                       1
# v6????                      1
# Name: electrodes_problems, dtype: int64

# %%
YI[YI.rhythm_diag == 'AFIB'].electrodes_problems.value_counts()
# Out:
# V1    1
# Name: electrodes_problems, dtype: int64

# %%
YI[YI.rhythm_diag == 'SR'].static_noise.value_counts()
# Out:
#  , I-AVR,             785
#  , I-AVF,             737
#  , alles,             350
#  , I-V1,              115
#  , I-V2,              104
#                      ...
#  , I,III-AVF,           1
#  , AVL,V2,              1
#  , I,II,AVL,AVF,        1
#  , I,V2,                1
#  , I,II,V5,             1
# Name: static_noise, Length: 104, dtype: int64

# %%
YI[YI.rhythm_diag == 'AFIB'].static_noise.value_counts()
# Out:
#  , alles,                     69
#  , I-AVF,                     65
#  , I-AVR,                     38
#  , I-V1,                      22
#  , I-V2,                      21
#  , mittel,                     8
#  , leicht,                     6
#  , I-AVL,                      5
#  , alles, noisy recording,     4
#  , noisy recording,            2
#  , V6,                         2
#  , I-V3,                       2
#  , I,II,                       2
# I,III,AVF,AVL,V2,  ,           1
#  , I,II,III,AVL,               1
#  , I -AVF,                     1
# V1,  ,                         1
#  , stark,                      1
#  , V2,                         1
#  , I,III,V5,                   1
#  , I,                          1
#  , I - AVR,                    1
#  , I,II,AVL,AVR,               1
#  , I - AVF,                    1
#  , I,II,AVL-AVF,               1
#  , noise,                      1
#  , I,II,AVR,                   1
#  , V1,V2,                      1
#  , I,II,AVR,V1,                1
#  , V5,V6,                      1
#  , V1,                         1
# Name: static_noise, dtype: int64

# %%
YI[YI.rhythm_diag == 'SR'].burst_noise.value_counts()
# Out:
# alles          93
# I-AVF          41
# V2             18
# V1             18
# I-AVR          18
#                ..
# III,AVL         1
#                 1
# v3,4            1
# I,II,AVL-V2     1
# I-AVL           1
# Name: burst_noise, Length: 78, dtype: int64

# %%
YI[YI.rhythm_diag == 'AFIB'].burst_noise.value_counts()
# Out:
# V1              27
# V1,V2           25
# alles           22
# I-V1             7
# I-V2             5
# I-V3             4
# v6               3
# I-AVF            3
# I-V5             2
# II               2
# V2               2
# II,III,V1,V2     2
# II,V1,V2         1
# V1-V5            1
# I,II,V1          1
# v4,6             1
# II-V1            1
# v3               1
# II-AVL,V1,V2     1
# v1,2             1
# V3               1
# alle             1
# V1-V6            1
# V1-V4            1
# v1-6             1
# III,V1           1
# V1,V5            1
# I,III,AVL        1
# I,II             1
# v4, v5           1
# V1,V2,V5         1
# Name: burst_noise, dtype: int64

# %%
YI[YI.rhythm_diag == 'OTHER'][['age', 'sex', 'height', 'weight']].describe()
# Out:
#                age          sex      height       weight
# count  3527.000000  3541.000000  871.000000  1153.000000
# mean     60.394386     0.460322  166.688863    69.849089
# std      18.631243     0.498494   11.660952    16.141242
# min       4.000000     0.000000    6.000000    20.000000
# 25%      50.000000     0.000000  160.000000    59.000000
# 50%      64.000000     0.000000  168.000000    69.000000
# 75%      74.000000     1.000000  174.000000    79.000000
# max      95.000000     1.000000  192.000000   185.000000

# %%
df_afib = YI[YI.rhythm_diag == 'AFIB'][['age', 'sex', 'height', 'weight']]
df_sr = YI[YI.rhythm_diag == 'SR'][['age', 'sex', 'height', 'weight']]

# %%
plt.figure(figsize=(10, 6))
sns.distplot(df_sr['age'], hist=False, label='SR')
sns.distplot(df_afib['age'], hist=False, label='AFIB');
# Out:
# c:\python38\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# c:\python38\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
def aggregate_rhythm(y_dic):
    tmp = []
    for key in y_dic.keys():
        if key in agg_df.index:
            tmp.append(agg_df.loc[key].diagnostic_class)
    return list(set(tmp))

# %%
def aggregate_rhythm_2(y_dic):
    tmp = []
    for key in y_dic.keys():
        if key in agg_df.index:
            tmp.append(agg_df.loc[key].rhythm_class)
    return list(set(tmp))

# %%
YI = Y.copy()

# %%
YI['rhythm_class'] = Y.scp_codes.apply(aggregate_rhythm)

# %%
YI.head()
# Out:
#         patient_id   age  sex  height  weight  nurse  site     device  \
# ecg_id
# 1          15709.0  56.0    1     NaN    63.0    2.0   0.0  CS-12   E
# 2          13243.0  19.0    0     NaN    70.0    2.0   0.0  CS-12   E
# 3          20372.0  37.0    1     NaN    69.0    2.0   0.0  CS-12   E
# 4          17014.0  24.0    0     NaN    82.0    2.0   0.0  CS-12   E
# 5          17448.0  19.0    1     NaN    70.0    2.0   0.0  CS-12   E
#
#              recording_date                                  report  ...  \
# ecg_id                                                               ...
# 1       1984-11-09 09:17:34  sinusrhythmus periphere niederspannung  ...
# 2       1984-11-14 12:55:37     sinusbradykardie sonst normales ekg  ...
# 3       1984-11-15 12:49:10              sinusrhythmus normales ekg  ...
# 4       1984-11-15 13:44:57              sinusrhythmus normales ekg  ...
# 5       1984-11-17 10:43:15              sinusrhythmus normales ekg  ...
#
#         baseline_drift static_noise burst_noise electrodes_problems  \
# ecg_id
# 1                  NaN    , I-V1,           NaN                 NaN
# 2                  NaN          NaN         NaN                 NaN
# 3                  NaN          NaN         NaN                 NaN
# 4         , II,III,AVF          NaN         NaN                 NaN
# 5        , III,AVR,AVF          NaN         NaN                 NaN
#
#         extra_beats  pacemaker  strat_fold                filename_lr  \
# ecg_id
# 1               NaN        NaN           3  records100/00000/00001_lr
# 2               NaN        NaN           2  records100/00000/00002_lr
# 3               NaN        NaN           5  records100/00000/00003_lr
# 4               NaN        NaN           3  records100/00000/00004_lr
# 5               NaN        NaN           4  records100/00000/00005_lr
#
#                       filename_hr rhythm_class
# ecg_id
# 1       records500/00000/00001_hr        [nan]
# 2       records500/00000/00002_hr        [nan]
# 3       records500/00000/00003_hr        [nan]
# 4       records500/00000/00004_hr        [nan]
# 5       records500/00000/00005_hr        [nan]
#
# [5 rows x 28 columns]

# %%
Y2 = Y.copy()

# %%
YI['rhythm_class'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [nan]    21066
# []         771
# Name: rhythm_class, dtype: int64

# %%
agg_df
# Out:
#                                              description  diagnostic  form  \
# SR                                          sinus rhythm         NaN   NaN
# AFIB                                 atrial fibrillation         NaN   NaN
# STACH                                  sinus tachycardia         NaN   NaN
# SARRH                                   sinus arrhythmia         NaN   NaN
# SBRAD                                  sinus bradycardia         NaN   NaN
# PACE             normal functioning artificial pacemaker         NaN   NaN
# SVARR                        supraventricular arrhythmia         NaN   NaN
# BIGU   bigeminal pattern (unknown origin, SV or Ventr...         NaN   NaN
# AFLT                                      atrial flutter         NaN   NaN
# SVTAC                       supraventricular tachycardia         NaN   NaN
# PSVT             paroxysmal supraventricular tachycardia         NaN   NaN
# TRIGU  trigeminal pattern (unknown origin, SV or Vent...         NaN   NaN
#
#        rhythm diagnostic_class diagnostic_subclass  \
# SR        1.0              NaN                 NaN
# AFIB      1.0              NaN                 NaN
# STACH     1.0              NaN                 NaN
# SARRH     1.0              NaN                 NaN
# SBRAD     1.0              NaN                 NaN
# PACE      1.0              NaN                 NaN
# SVARR     1.0              NaN                 NaN
# BIGU      1.0              NaN                 NaN
# AFLT      1.0              NaN                 NaN
# SVTAC     1.0              NaN                 NaN
# PSVT      1.0              NaN                 NaN
# TRIGU     1.0              NaN                 NaN
#
#                                       Statement Category  \
# SR     Statements related to impulse formation (abnor...
# AFIB   Statements related to impulse formation (abnor...
# STACH  Statements related to impulse formation (abnor...
# SARRH  Statements related to impulse formation (abnor...
# SBRAD  Statements related to impulse formation (abnor...
# PACE              Pacemaker types and pacemaker function
# SVARR  Statements related to impulse formation (abnor...
# BIGU   Statements related to ectopic rhythm abnormali...
# AFLT   Statements related to impulse formation (abnor...
# SVTAC  Statements related to impulse formation (abnor...
# PSVT   Statements related to impulse formation (abnor...
# TRIGU  Statements related to ectopic rhythm abnormali...
#
#                            SCP-ECG Statement Description  AHA code  \
# SR                                          sinus rhythm      20.0
# AFIB                                 atrial fibrillation      50.0
# STACH                                  sinus tachycardia      21.0
# SARRH                                   sinus arrhythmia      23.0
# SBRAD                                  sinus bradycardia      22.0
# PACE             normal functioning artificial pacemaker       NaN
# SVARR                        supraventricular arrhythmia       NaN
# BIGU   bigeminal pattern (unknown origin, SV or Ventr...       NaN
# AFLT                                      atrial flutter      51.0
# SVTAC                       supraventricular tachycardia      55.0
# PSVT             paroxysmal supraventricular tachycardia       NaN
# TRIGU  trigeminal pattern (unknown origin, SV or Vent...       NaN
#
#                        aECG REFID CDISC Code DICOM Code
# SR          MDC_ECG_RHY_SINUS_RHY        NaN        NaN
# AFIB          MDC_ECG_RHY_ATR_FIB        NaN   D3-31520
# STACH     MDC_ECG_RHY_SINUS_TACHY        NaN        NaN
# SARRH     MDC_ECG_RHY_SINUS_ARRHY        NaN        NaN
# SBRAD     MDC_ECG_RHY_SINUS_BRADY        NaN        NaN
# PACE                          NaN        NaN        NaN
# SVARR                         NaN        NaN        NaN
# BIGU                          NaN        NaN        NaN
# AFLT         MDC_ECG_RHY_ATR_FLUT        NaN        NaN
# SVTAC        MDC_ECG_RHY_SV_TACHY        NaN   D3-31290
# PSVT   MDC_ECG_RHY_SV_TACHY_PAROX        NaN        NaN
# TRIGU                         NaN        NaN        NaN

# %%
def aggregate_rhythm(y_dic):
    tmp = []
    for key in y_dic.keys():
        if key in agg_df.index:
            tmp.append(agg_df.loc[key].description)
    return list(set(tmp))

# %%
Y3 = Y.copy()
Y3['rhythm_class'] = Y.scp_codes.apply(aggregate_rhythm)

# %%
Y3.head()
# Out:
#         patient_id   age  sex  height  weight  nurse  site     device  \
# ecg_id
# 1          15709.0  56.0    1     NaN    63.0    2.0   0.0  CS-12   E
# 2          13243.0  19.0    0     NaN    70.0    2.0   0.0  CS-12   E
# 3          20372.0  37.0    1     NaN    69.0    2.0   0.0  CS-12   E
# 4          17014.0  24.0    0     NaN    82.0    2.0   0.0  CS-12   E
# 5          17448.0  19.0    1     NaN    70.0    2.0   0.0  CS-12   E
#
#              recording_date                                  report  ...  \
# ecg_id                                                               ...
# 1       1984-11-09 09:17:34  sinusrhythmus periphere niederspannung  ...
# 2       1984-11-14 12:55:37     sinusbradykardie sonst normales ekg  ...
# 3       1984-11-15 12:49:10              sinusrhythmus normales ekg  ...
# 4       1984-11-15 13:44:57              sinusrhythmus normales ekg  ...
# 5       1984-11-17 10:43:15              sinusrhythmus normales ekg  ...
#
#         baseline_drift static_noise burst_noise electrodes_problems  \
# ecg_id
# 1                  NaN    , I-V1,           NaN                 NaN
# 2                  NaN          NaN         NaN                 NaN
# 3                  NaN          NaN         NaN                 NaN
# 4         , II,III,AVF          NaN         NaN                 NaN
# 5        , III,AVR,AVF          NaN         NaN                 NaN
#
#         extra_beats  pacemaker  strat_fold                filename_lr  \
# ecg_id
# 1               NaN        NaN           3  records100/00000/00001_lr
# 2               NaN        NaN           2  records100/00000/00002_lr
# 3               NaN        NaN           5  records100/00000/00003_lr
# 4               NaN        NaN           3  records100/00000/00004_lr
# 5               NaN        NaN           4  records100/00000/00005_lr
#
#                       filename_hr         rhythm_class
# ecg_id
# 1       records500/00000/00001_hr       [sinus rhythm]
# 2       records500/00000/00002_hr  [sinus bradycardia]
# 3       records500/00000/00003_hr       [sinus rhythm]
# 4       records500/00000/00004_hr       [sinus rhythm]
# 5       records500/00000/00005_hr       [sinus rhythm]
#
# [5 rows x 28 columns]

# %%
Y3['rhythm_class'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [sinus rhythm]                                                                           16721
# [atrial fibrillation]                                                                     1484
# [sinus tachycardia]                                                                        805
# []                                                                                         771
# [sinus arrhythmia]                                                                         765
# [sinus bradycardia]                                                                        629
# [normal functioning artificial pacemaker]                                                  287
# [supraventricular arrhythmia]                                                              150
# [sinus rhythm, bigeminal pattern (unknown origin, SV or Ventricular)]                       37
# [atrial flutter]                                                                            36
# [bigeminal pattern (unknown origin, SV or Ventricular)]                                     22
# [atrial flutter, atrial fibrillation]                                                       15
# [trigeminal pattern (unknown origin, SV or Ventricular), sinus rhythm]                      11
# [supraventricular tachycardia]                                                              10
# [paroxysmal supraventricular tachycardia]                                                   10
# [bigeminal pattern (unknown origin, SV or Ventricular), sinus tachycardia]                   9
# [supraventricular tachycardia, paroxysmal supraventricular tachycardia]                      8
# [atrial fibrillation, bigeminal pattern (unknown origin, SV or Ventricular)]                 7
# [atrial flutter, supraventricular tachycardia]                                               6
# [atrial flutter, sinus tachycardia]                                                          5
# [trigeminal pattern (unknown origin, SV or Ventricular), sinus tachycardia]                  4
# [atrial flutter, supraventricular arrhythmia]                                                4
# [atrial fibrillation, normal functioning artificial pacemaker]                               4
# [trigeminal pattern (unknown origin, SV or Ventricular)]                                     4
# [sinus bradycardia, bigeminal pattern (unknown origin, SV or Ventricular)]                   3
# [atrial flutter, sinus rhythm]                                                               3
# [sinus rhythm, normal functioning artificial pacemaker]                                      3
# [sinus bradycardia, sinus arrhythmia]                                                        3
# [sinus arrhythmia, bigeminal pattern (unknown origin, SV or Ventricular)]                    2
# [sinus tachycardia, bigeminal pattern (unknown origin, SV or Ventricular)]                   2
# [atrial fibrillation, atrial flutter]                                                        2
# [sinus rhythm, sinus arrhythmia]                                                             2
# [supraventricular arrhythmia, paroxysmal supraventricular tachycardia]                       2
# [sinus rhythm, atrial flutter]                                                               2
# [sinus bradycardia, normal functioning artificial pacemaker]                                 2
# [sinus rhythm, supraventricular tachycardia]                                                 1
# [sinus rhythm, paroxysmal supraventricular tachycardia]                                      1
# [atrial fibrillation, supraventricular tachycardia]                                          1
# [trigeminal pattern (unknown origin, SV or Ventricular), supraventricular arrhythmia]        1
# [sinus rhythm, supraventricular tachycardia, paroxysmal supraventricular tachycardia]        1
# [sinus tachycardia, paroxysmal supraventricular tachycardia]                                 1
# [atrial fibrillation, paroxysmal supraventricular tachycardia]                               1
# Name: rhythm_class, dtype: int64

# %%
Y3.shape
# Out:
# (21837, 28)

# %%
X.shape
# Out:
# (21837, 1000, 12)

# %%
X[0,0,1]
# Out:
# -0.055

# %%
Y3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21837 entries, 1 to 21837
# Data columns (total 28 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   patient_id                    21837 non-null  float64
#  1   age                           21748 non-null  float64
#  2   sex                           21837 non-null  int64
#  3   height                        6983 non-null   float64
#  4   weight                        9429 non-null   float64
#  5   nurse                         20328 non-null  float64
#  6   site                          21819 non-null  float64
#  7   device                        21837 non-null  object
#  8   recording_date                21837 non-null  object
#  9   report                        21837 non-null  object
#  10  scp_codes                     21837 non-null  object
#  11  heart_axis                    13332 non-null  object
#  12  infarction_stadium1           5626 non-null   object
#  13  infarction_stadium2           103 non-null    object
#  14  validated_by                  12426 non-null  float64
#  15  second_opinion                21837 non-null  bool
#  16  initial_autogenerated_report  21837 non-null  bool
#  17  validated_by_human            21837 non-null  bool
#  18  baseline_drift                1607 non-null   object
#  19  static_noise                  3262 non-null   object
#  20  burst_noise                   613 non-null    object
#  21  electrodes_problems           30 non-null     object
#  22  extra_beats                   1954 non-null   object
#  23  pacemaker                     293 non-null    object
#  24  strat_fold                    21837 non-null  int64
#  25  filename_lr                   21837 non-null  object
#  26  filename_hr                   21837 non-null  object
#  27  rhythm_class                  21837 non-null  object
# dtypes: bool(3), float64(7), int64(2), object(16)
# memory usage: 4.9+ MB
