# %% [markdown]
# # Testing Model

# %% [markdown]
# ## Import Libraries and setup

# %%
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.signal import butter, iirnotch, sosfilt, sosfreqz, lfilter, filtfilt
import biosppy

import tensorflow as tf
from tensorflow.keras import Sequential,utils
from tensorflow.keras.layers import Input, Flatten, Dense, Conv1D, MaxPooling1D, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, LearningRateScheduler
from tensorflow.keras.models import load_model

from sklearn.utils import resample
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

plt.rcParams["figure.figsize"] = (10,5)

# %% [markdown]
# ## Main Functions

# %%
def butter_highpass(cutoff, sample_rate, order, data):
    nyq = 0.5 * sample_rate
    normal_cutoff = cutoff / nyq
    b, a = butter(order, normal_cutoff, btype='high', analog=False)
    final_filtered_highpass = filtfilt(b, a, data)
    return final_filtered_highpass


def butter_lowpass(cutoff, sample_rate, order, data, slice=-1):
    nyq = 0.5 * sample_rate
    normal_cutoff = cutoff / nyq
    b, a = butter(order, normal_cutoff, btype='low', analog=False)
    filtered_lowpass = lfilter(b, a, data)
    return filtered_lowpass


def moving_average_filter(x, w):
    m_a_filtered = np.convolve(x, np.ones(w), 'same') / w
    return m_a_filtered


def filter_data(data, sample_rate=100):
    filtered_data_low = butter_lowpass(41.09, sample_rate, 5, data)
    filtered_data_high = butter_highpass(0.48, sample_rate, 2, filtered_data_low)
    #final_filtered_data = moving_average_filter(filtered_data_high, 3)
    return filtered_data_high

# %%
def correct_rpeaks(signal, rpeaks=None, sampling_rate=100, tol=0.05):
    """Correct R-peak locations to the maximum within a tolerance.
    Parameters
    ----------
    signal : array
        ECG signal.
    rpeaks : array
        R-peak location indices.
    sampling_rate : int, float, optional
        Sampling frequency (Hz).
    tol : int, float, optional
        Correction tolerance (seconds).
    Returns
    -------
    rpeaks : array
        Cerrected R-peak location indices.
    Notes
    -----
    * The tolerance is defined as the time interval :math:`[R-tol, R+tol[`.
    """

    # check inputs
    if signal is None:
        raise TypeError("Please specify an input signal.")

    if rpeaks is None:
        raise TypeError("Please specify the input R-peaks.")

    tol = int(tol * sampling_rate)
    length = len(signal)

    newR = []
    for r in rpeaks:
        a = r - tol
        if a < 0:
            continue
        b = r + tol
        if b > length:
            break
        newR.append(a + np.argmax(signal[a:b]))

    newR = sorted(list(set(newR)))
    newR = np.array(newR, dtype='int')

    return newR

# %%
def _extract_heartbeats(signal=None, rpeaks=None, before=200, after=400):
    """Extract heartbeat templates from an ECG signal, given a list of
    R-peak locations.
    Parameters
    ----------
    signal : array
        Input ECG signal.
    rpeaks : array
        R-peak location indices.
    before : int, optional
        Number of samples to include before the R peak.
    after : int, optional
        Number of samples to include after the R peak.
    Returns
    -------
    templates : array
        Extracted heartbeat templates.
    rpeaks : array
        Corresponding R-peak location indices of the extracted heartbeat
        templates.
    """

    R = np.sort(rpeaks)
    length = len(signal)
    templates = []
    newR = []

    for r in R:
        a = r - before
        if a < 0:
            continue
        b = r + after
        if b > length:
            break
        templates.append(signal[a:b])
        newR.append(r)

    templates = np.array(templates)
    newR = np.array(newR, dtype='int')

    return templates, newR

# %%
def extract_heartbeats(signal=None, rpeaks=None, sampling_rate=1000.,
                       before=0.2, after=0.4):
    """Extract heartbeat templates from an ECG signal, given a list of
    R-peak locations.
    Parameters
    ----------
    signal : array
        Input ECG signal.
    rpeaks : array
        R-peak location indices.
    sampling_rate : int, float, optional
        Sampling frequency (Hz).
    before : float, optional
        Window size to include before the R peak (seconds).
    after : int, optional
        Window size to include after the R peak (seconds).
    Returns
    -------
    templates : array
        Extracted heartbeat templates.
    rpeaks : array
        Corresponding R-peak location indices of the extracted heartbeat
        templates.
    """

    # check inputs
    if signal is None:
        raise TypeError("Please specify an input signal.")

    if rpeaks is None:
        raise TypeError("Please specify the input R-peak locations.")

    if before < 0:
        raise ValueError("Please specify a non-negative 'before' value.")
    if after < 0:
        raise ValueError("Please specify a non-negative 'after' value.")

    # convert delimiters to samples
    before = int(before * sampling_rate)
    after = int(after * sampling_rate)

    # get heartbeats
    templates, newR = _extract_heartbeats(signal=signal,
                                          rpeaks=rpeaks,
                                          before=before,
                                          after=after)

    return templates, newR

# %%
def get_complete_Heartbit(sample, sampling_rate=100,plot=True):
    filtered_sample = filter_data(sample,sampling_rate)
    data = filtered_sample.T
    signals = []
    indices = []
    count = 1
    peaks = biosppy.signals.ecg.christov_segmenter(
        signal=data, sampling_rate=sampling_rate)[0]
    rpeaks = correct_rpeaks(signal=data,rpeaks=peaks, sampling_rate=100,tol=0.05)
    templates, rpeaks = extract_heartbeats(signal=data,rpeaks=rpeaks,sampling_rate=100,before=0.2,after=0.4)
    if plot:
        ts_tmpl = np.linspace(-0.2, 0.4, templates.shape[1], endpoint=False)
        fig = plt.figure()
        gs = gridspec.GridSpec(6, 2)
        ax4 = fig.add_subplot(gs[1:5, 1])
        plt.plot(ts_tmpl, templates.T, 'm', linewidth=1.5, alpha=0.7)
        ax4.set_xlabel('Time (s)')
        ax4.set_ylabel('Amplitude')
        ax4.set_title('Templates')
        ax4.grid()
    #return templates, rpeaks
    return templates

# %%
def get_heart_beat(data):
    templates = []
    templates_aux = []
    for i in range(len(data)-1): 
        templates_aux = get_complete_Heartbit(data[i], 100,False)
        k = len(templates);
        for j in range(len(templates_aux)-1):
            templates.append(templates_aux[j])
    return np.array(templates)

# %%
def plot_conf_matrix(y_test, y_pred):
    plt.figure(figsize=(8,6))
    sns.heatmap(confusion_matrix(y_test,y_pred), cmap='Blues', annot=True, fmt='g');
    plt.title('Confusion Matrix')
    plt.xlabel("Predictions")
    plt.ylabel("Real values")
    plt.show()

# %% [markdown]
# ## Getting Test data

# %%
df = pd.read_csv("ECG_Rhythm_Lead_I.csv")
del df["Unnamed: 0"]
df.shape
# Out:
# (21837, 1006)

# %%
df = df.loc[df.rhythm_diag != 'OTHER']

# %%
df['rhythm_diag'] = df['rhythm_diag'].map(dict(AFIB=1, SR=0))
df.rhythm_diag.value_counts()
# Out:
# 0    16782
# 1     1514
# Name: rhythm_diag, dtype: int64

# %%
df_minority = df[df['rhythm_diag']==1]
df_majority = df[df['rhythm_diag']==0]
maj_class = resample(df_majority,
                     replace=True,
                     n_samples=1514,
                     random_state=123)
df=pd.concat([df_minority,maj_class])

# %%
df.rhythm_diag.value_counts()
# Out:
# 0    1514
# 1    1514
# Name: rhythm_diag, dtype: int64

# %%
df_sr = df[df.rhythm_diag == 0]
df_sr = df_sr.drop(['ecg_id', 'age', 'sex', 'height',
                    'weight', 'rhythm_diag'], axis=1)
df_sr.reset_index(drop= True ,inplace=True)
df_sr.shape
# Out:
# (1514, 1000)

# %%
df_afib = df[df.rhythm_diag == 1]
df_afib = df_afib.drop(
    ['ecg_id', 'age', 'sex', 'height', 'weight', 'rhythm_diag'], axis=1)
df_afib.reset_index(drop=True, inplace=True)
df_afib.shape
# Out:
# (1514, 1000)

# %%
X_sr = df_sr.values
X_afib = df_afib.values

# %%
def get_heart_beat(data):
    templates = []
    templates_aux = []
    for i in range(len(data)-1): 
        templates_aux = get_complete_Heartbit(data[i], 100,False)
        k = len(templates);
        for j in range(len(templates_aux)-1):
            templates.append(templates_aux[j])
    return np.array(templates)

# %%
X_sr = get_heart_beat(X_sr)
X_sr.shape
# Out:
# (15369, 60)

# %%
y_sr = np.zeros(len(X_sr))
y_sr.shape
# Out:
# (15369,)

# %%
X_afib = get_heart_beat(X_afib)
X_afib.shape
# Out:
# (19039, 60)

# %%
y_afib = np.ones(len(X_afib))
y_afib.shape
# Out:
# (19039,)

# %%
X = np.concatenate((X_sr, X_afib), axis=0)
X.shape
# Out:
# (34408, 60)

# %%
y = np.concatenate((y_sr, y_afib), axis=0)
y.shape
# Out:
# (34408,)

# %%
# Getting data
from numpy import load
#Xt = load('../data/train_test_data/X.npy')
#yt = load('../data/train_test_data/y.npy')
Xt = X
yt = y

# %%
plt.plot(Xt[0])
plt.title("ECG Sample")
plt.grid()
plt.show()

# %%
# Split data, normalize and reshape
X_train, X_test, y_train, y_test = train_test_split(Xt,yt,
                                                    test_size=0.20,
                                                    random_state=21)
X_train = X_train - X_train.min()
X_train = X_train/X_train.max()

X_test = X_test - X_test.min()
X_test = X_test/X_test.max()

X_train = np.expand_dims(X_train, 2)
X_test = np.expand_dims(X_test, 2)

# %%
print(X_train.shape, X_test.shape)
samples, features, depht = X_train.shape
# Out:
# (27526, 60, 1) (6882, 60, 1)

# %%
def group_layer(model):
    model.add(
        Conv1D(32,
               kernel_size=5,
               strides=1,
               padding='same',
               activation='relu'))
    model.add(
        Conv1D(32,
               kernel_size=5,
               strides=1,
               padding='same',
               activation='relu'))
    model.add(MaxPooling1D(pool_size=5, strides=2))
    return model

# %%
model = Sequential()
model.add(Input(shape=(features, depht)))
model=group_layer(model)
model=group_layer(model)
model=group_layer(model)
model.add(Flatten())
model.add(Dense(32, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# Out:
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.

# %%
#model = load_model('../models/cnn_v1.h5')
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 60, 32)            192
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 60, 32)            5152
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 28, 32)            0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 28, 32)            5152
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 28, 32)            5152
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 12, 32)            0
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 12, 32)            5152
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 12, 32)            5152
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 4, 32)             0
# _________________________________________________________________
# flatten (Flatten)            (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 32)                4128
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                1056
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 31,169
# Trainable params: 31,169
# Non-trainable params: 0
# _________________________________________________________________

# %%
lr = 0.001

# %%
opt = Adam(learning_rate=lr)
model.compile(loss='binary_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])

# %%
early_stop = EarlyStopping(monitor='val_loss', 
                           mode='min', 
                           verbose=1, 
                           patience=25)

# %%
EPOCHS = 100

history = model.fit(X_train,
                    y_train,
                    epochs=EPOCHS,
                    validation_split=0.2,
                    verbose=1,
                    callbacks=[early_stop])
# Out:
# Epoch 1/100
# 689/689 [==============================] - 9s 11ms/step - loss: 0.6877 - accuracy: 0.5543 - val_loss: 0.6856 - val_accuracy: 0.5474
# Epoch 2/100
# 689/689 [==============================] - 7s 10ms/step - loss: 0.5198 - accuracy: 0.7479 - val_loss: 0.3845 - val_accuracy: 0.8507
# Epoch 3/100
# 689/689 [==============================] - 8s 11ms/step - loss: 0.3712 - accuracy: 0.8552 - val_loss: 0.3454 - val_accuracy: 0.8663
# Epoch 4/100
# 689/689 [==============================] - 7s 10ms/step - loss: 0.3398 - accuracy: 0.8676 - val_loss: 0.3197 - val_accuracy: 0.8770
# Epoch 5/100
# 689/689 [==============================] - 7s 10ms/step - loss: 0.3261 - accuracy: 0.8703 - val_loss: 0.3095 - val_accuracy: 0.8792
# Epoch 6/100
# 689/689 [==============================] - 7s 10ms/step - loss: 0.3103 - accuracy: 0.8796 - val_loss: 0.2963 - val_accuracy: 0.8876
# Epoch 7/100
# 689/689 [==============================] - 7s 10ms/step - loss: 0.3056 - accuracy: 0.8802 - val_loss: 0.2988 - val_accuracy: 0.8847
# Epoch 8/100
# 689/689 [==============================] - 7s 10ms/step - loss: 0.2958 - accuracy: 0.8850 - val_loss: 0.2828 - val_accuracy: 0.8923
# Epoch 9/100
# 689/689 [==============================] - 7s 10ms/step - loss: 0.2925 - accuracy: 0.8854 - val_loss: 0.2792 - val_accuracy: 0.8967
# Epoch 10/100
# 689/689 [==============================] - 7s 10ms/step - loss: 0.2884 - accuracy: 0.8868 - val_loss: 0.2833 - val_accuracy: 0.8934
# Epoch 11/100
# 689/689 [==============================] - 7s 10ms/step - loss: 0.2802 - accuracy: 0.8904 - val_loss: 0.2804 - val_accuracy: 0.8919
# Epoch 12/100
# 689/689 [==============================] - 7s 10ms/step - loss: 0.2802 - accuracy: 0.8912 - val_loss: 0.2750 - val_accuracy: 0.8967
# Epoch 13/100
# 689/689 [==============================] - 7s 10ms/step - loss: 0.2809 - accuracy: 0.8906 - val_loss: 0.2669 - val_accuracy: 0.8988
# Epoch 14/100
# 689/689 [==============================] - 7s 10ms/step - loss: 0.2725 - accuracy: 0.8920 - val_loss: 0.2632 - val_accuracy: 0.8979
# Epoch 15/100
# 689/689 [==============================] - 7s 10ms/step - loss: 0.2677 - accuracy: 0.8947 - val_loss: 0.2691 - val_accuracy: 0.8952
# Epoch 16/100
# 689/689 [==============================] - 7s 10ms/step - loss: 0.2669 - accuracy: 0.8940 - val_loss: 0.2686 - val_accuracy: 0.9007
# Epoch 17/100
# 689/689 [==============================] - 7s 11ms/step - loss: 0.2629 - accuracy: 0.8963 - val_loss: 0.2579 - val_accuracy: 0.9032
# Epoch 18/100
# 689/689 [==============================] - 7s 10ms/step - loss: 0.2613 - accuracy: 0.8974 - val_loss: 0.2936 - val_accuracy: 0.8819
# Epoch 19/100
# 689/689 [==============================] - 7s 10ms/step - loss: 0.2582 - accuracy: 0.8991 - val_loss: 0.2502 - val_accuracy: 0.9063
# Epoch 20/100
# 689/689 [==============================] - 7s 10ms/step - loss: 0.2562 - accuracy: 0.8979 - val_loss: 0.2463 - val_accuracy: 0.9092
# Epoch 21/100
# 689/689 [==============================] - 7s 10ms/step - loss: 0.2492 - accuracy: 0.9030 - val_loss: 0.2594 - val_accuracy: 0.9039
# Epoch 22/100
# 689/689 [==============================] - 7s 10ms/step - loss: 0.2502 - accuracy: 0.9014 - val_loss: 0.2492 - val_accuracy: 0.9041
# Epoch 23/100
# 689/689 [==============================] - 7s 10ms/step - loss: 0.2454 - accuracy: 0.9023 - val_loss: 0.2502 - val_accuracy: 0.9034
# Epoch 24/100
# 689/689 [==============================] - 7s 10ms/step - loss: 0.2464 - accuracy: 0.9036 - val_loss: 0.2585 - val_accuracy: 0.8987
# Epoch 25/100
# 689/689 [==============================] - 7s 10ms/step - loss: 0.2444 - accuracy: 0.9031 - val_loss: 0.2435 - val_accuracy: 0.9076
# Epoch 26/100
# 689/689 [==============================] - 8s 11ms/step - loss: 0.2412 - accuracy: 0.9050 - val_loss: 0.2440 - val_accuracy: 0.9065
# Epoch 27/100
# 689/689 [==============================] - 7s 10ms/step - loss: 0.2429 - accuracy: 0.9041 - val_loss: 0.2431 - val_accuracy: 0.9066
# Epoch 28/100
# 689/689 [==============================] - 7s 10ms/step - loss: 0.2374 - accuracy: 0.9075 - val_loss: 0.3786 - val_accuracy: 0.8391
# Epoch 29/100
# 689/689 [==============================] - 7s 10ms/step - loss: 0.2358 - accuracy: 0.9084 - val_loss: 0.2484 - val_accuracy: 0.9086
# Epoch 30/100
# 689/689 [==============================] - 7s 10ms/step - loss: 0.2347 - accuracy: 0.9074 - val_loss: 0.2477 - val_accuracy: 0.9007
# Epoch 31/100
# 689/689 [==============================] - 7s 10ms/step - loss: 0.2339 - accuracy: 0.9094 - val_loss: 0.2410 - val_accuracy: 0.9083
# Epoch 32/100
# 689/689 [==============================] - 7s 10ms/step - loss: 0.2303 - accuracy: 0.9107 - val_loss: 0.2705 - val_accuracy: 0.8947
# Epoch 33/100
# 689/689 [==============================] - 7s 10ms/step - loss: 0.2276 - accuracy: 0.9110 - val_loss: 0.2430 - val_accuracy: 0.9066
# Epoch 34/100
# 689/689 [==============================] - 7s 10ms/step - loss: 0.2254 - accuracy: 0.9130 - val_loss: 0.2322 - val_accuracy: 0.9143
# Epoch 35/100
# 689/689 [==============================] - 7s 10ms/step - loss: 0.2281 - accuracy: 0.9098 - val_loss: 0.2619 - val_accuracy: 0.8981
# Epoch 36/100
# 689/689 [==============================] - 7s 10ms/step - loss: 0.2221 - accuracy: 0.9140 - val_loss: 0.2342 - val_accuracy: 0.9148
# Epoch 37/100
# 689/689 [==============================] - 7s 10ms/step - loss: 0.2215 - accuracy: 0.9135 - val_loss: 0.2378 - val_accuracy: 0.9121
# Epoch 38/100
# 689/689 [==============================] - 7s 10ms/step - loss: 0.2226 - accuracy: 0.9161 - val_loss: 0.2234 - val_accuracy: 0.9174
# Epoch 39/100
# 689/689 [==============================] - 7s 10ms/step - loss: 0.2200 - accuracy: 0.9153 - val_loss: 0.2489 - val_accuracy: 0.9045
# Epoch 40/100
# 689/689 [==============================] - 7s 10ms/step - loss: 0.2170 - accuracy: 0.9169 - val_loss: 0.2748 - val_accuracy: 0.8945
# Epoch 41/100
# 689/689 [==============================] - 7s 10ms/step - loss: 0.2185 - accuracy: 0.9156 - val_loss: 0.2382 - val_accuracy: 0.9088
# Epoch 42/100
# 689/689 [==============================] - 7s 10ms/step - loss: 0.2153 - accuracy: 0.9167 - val_loss: 0.2289 - val_accuracy: 0.9137
# Epoch 43/100
# 689/689 [==============================] - 7s 10ms/step - loss: 0.2163 - accuracy: 0.9173 - val_loss: 0.2214 - val_accuracy: 0.9174
# Epoch 44/100
# 689/689 [==============================] - 7s 10ms/step - loss: 0.2131 - accuracy: 0.9194 - val_loss: 0.2220 - val_accuracy: 0.9175
# Epoch 45/100
# 689/689 [==============================] - 7s 10ms/step - loss: 0.2107 - accuracy: 0.9189 - val_loss: 0.2302 - val_accuracy: 0.9123
# Epoch 46/100
# 689/689 [==============================] - 7s 9ms/step - loss: 0.2085 - accuracy: 0.9201 - val_loss: 0.2259 - val_accuracy: 0.9119
# Epoch 47/100
# 689/689 [==============================] - 7s 9ms/step - loss: 0.2062 - accuracy: 0.9213 - val_loss: 0.2268 - val_accuracy: 0.9114
# Epoch 48/100
# 689/689 [==============================] - 7s 10ms/step - loss: 0.2082 - accuracy: 0.9214 - val_loss: 0.2593 - val_accuracy: 0.9061
# Epoch 49/100
# 689/689 [==============================] - 7s 9ms/step - loss: 0.2069 - accuracy: 0.9199 - val_loss: 0.2697 - val_accuracy: 0.8934
# Epoch 50/100
# 689/689 [==============================] - 7s 10ms/step - loss: 0.2070 - accuracy: 0.9218 - val_loss: 0.2156 - val_accuracy: 0.9192
# Epoch 51/100
# 689/689 [==============================] - 7s 9ms/step - loss: 0.2042 - accuracy: 0.9214 - val_loss: 0.2113 - val_accuracy: 0.9248
# Epoch 52/100
# 689/689 [==============================] - 7s 10ms/step - loss: 0.2025 - accuracy: 0.9236 - val_loss: 0.2288 - val_accuracy: 0.9119
# Epoch 53/100
# 689/689 [==============================] - 8s 11ms/step - loss: 0.2008 - accuracy: 0.9243 - val_loss: 0.2141 - val_accuracy: 0.9194
# Epoch 54/100
# 689/689 [==============================] - 7s 10ms/step - loss: 0.2010 - accuracy: 0.9238 - val_loss: 0.2651 - val_accuracy: 0.8918
# Epoch 55/100
# 689/689 [==============================] - 7s 9ms/step - loss: 0.2004 - accuracy: 0.9238 - val_loss: 0.2346 - val_accuracy: 0.9114
# Epoch 56/100
# 689/689 [==============================] - 7s 10ms/step - loss: 0.1983 - accuracy: 0.9236 - val_loss: 0.2324 - val_accuracy: 0.9112
# Epoch 57/100
# 689/689 [==============================] - 8s 11ms/step - loss: 0.1970 - accuracy: 0.9246 - val_loss: 0.2144 - val_accuracy: 0.9234
# Epoch 58/100
# 689/689 [==============================] - 7s 10ms/step - loss: 0.1981 - accuracy: 0.9233 - val_loss: 0.2056 - val_accuracy: 0.9241
# Epoch 59/100
# 689/689 [==============================] - 8s 12ms/step - loss: 0.1939 - accuracy: 0.9257 - val_loss: 0.2416 - val_accuracy: 0.9130
# Epoch 60/100
# 689/689 [==============================] - 8s 12ms/step - loss: 0.1982 - accuracy: 0.9249 - val_loss: 0.2200 - val_accuracy: 0.9201
# Epoch 61/100
# 689/689 [==============================] - 8s 12ms/step - loss: 0.1917 - accuracy: 0.9252 - val_loss: 0.2312 - val_accuracy: 0.9148
# Epoch 62/100
# 689/689 [==============================] - 8s 11ms/step - loss: 0.1951 - accuracy: 0.9260 - val_loss: 0.2145 - val_accuracy: 0.9210
# Epoch 63/100
# 689/689 [==============================] - 8s 11ms/step - loss: 0.1917 - accuracy: 0.9272 - val_loss: 0.2145 - val_accuracy: 0.9199
# Epoch 64/100
# 689/689 [==============================] - 8s 11ms/step - loss: 0.1922 - accuracy: 0.9259 - val_loss: 0.2101 - val_accuracy: 0.9223
# Epoch 65/100
# 689/689 [==============================] - 8s 11ms/step - loss: 0.1935 - accuracy: 0.9253 - val_loss: 0.2210 - val_accuracy: 0.9210
# Epoch 66/100
# 689/689 [==============================] - 7s 11ms/step - loss: 0.1899 - accuracy: 0.9275 - val_loss: 0.2579 - val_accuracy: 0.8985
# Epoch 67/100
# 689/689 [==============================] - 7s 11ms/step - loss: 0.1915 - accuracy: 0.9270 - val_loss: 0.2135 - val_accuracy: 0.9205
# Epoch 68/100
# 689/689 [==============================] - 7s 11ms/step - loss: 0.1878 - accuracy: 0.9288 - val_loss: 0.2173 - val_accuracy: 0.9195
# Epoch 69/100
# 689/689 [==============================] - 7s 11ms/step - loss: 0.1839 - accuracy: 0.9312 - val_loss: 0.2149 - val_accuracy: 0.9248
# Epoch 70/100
# 689/689 [==============================] - 7s 10ms/step - loss: 0.1881 - accuracy: 0.9278 - val_loss: 0.2058 - val_accuracy: 0.9250
# Epoch 71/100
# 689/689 [==============================] - 7s 10ms/step - loss: 0.1828 - accuracy: 0.9307 - val_loss: 0.2099 - val_accuracy: 0.9212
# Epoch 72/100
# 689/689 [==============================] - 7s 10ms/step - loss: 0.1839 - accuracy: 0.9294 - val_loss: 0.2111 - val_accuracy: 0.9239
# Epoch 73/100
# 689/689 [==============================] - 7s 11ms/step - loss: 0.1836 - accuracy: 0.9292 - val_loss: 0.2046 - val_accuracy: 0.9237
# Epoch 74/100
# 689/689 [==============================] - 7s 11ms/step - loss: 0.1843 - accuracy: 0.9283 - val_loss: 0.2157 - val_accuracy: 0.9215
# Epoch 75/100
# 689/689 [==============================] - 7s 10ms/step - loss: 0.1802 - accuracy: 0.9315 - val_loss: 0.2292 - val_accuracy: 0.9170
# Epoch 76/100
# 689/689 [==============================] - 7s 10ms/step - loss: 0.1789 - accuracy: 0.9314 - val_loss: 0.2045 - val_accuracy: 0.9259
# Epoch 77/100
# 689/689 [==============================] - 7s 10ms/step - loss: 0.1829 - accuracy: 0.9287 - val_loss: 0.2091 - val_accuracy: 0.9244
# Epoch 78/100
# 689/689 [==============================] - 7s 11ms/step - loss: 0.1769 - accuracy: 0.9333 - val_loss: 0.2089 - val_accuracy: 0.9223
# Epoch 79/100
# 689/689 [==============================] - 8s 11ms/step - loss: 0.1783 - accuracy: 0.9310 - val_loss: 0.2247 - val_accuracy: 0.9179
# Epoch 80/100
# 689/689 [==============================] - 8s 12ms/step - loss: 0.1764 - accuracy: 0.9322 - val_loss: 0.2304 - val_accuracy: 0.9155
# Epoch 81/100
# 689/689 [==============================] - 8s 11ms/step - loss: 0.1739 - accuracy: 0.9337 - val_loss: 0.2015 - val_accuracy: 0.9261
# Epoch 82/100
# 689/689 [==============================] - 8s 11ms/step - loss: 0.1750 - accuracy: 0.9328 - val_loss: 0.2246 - val_accuracy: 0.9154
# Epoch 83/100
# 689/689 [==============================] - 7s 11ms/step - loss: 0.1771 - accuracy: 0.9326 - val_loss: 0.2172 - val_accuracy: 0.9212
# Epoch 84/100
# 689/689 [==============================] - 7s 10ms/step - loss: 0.1729 - accuracy: 0.9335 - val_loss: 0.2154 - val_accuracy: 0.9252
# Epoch 85/100
# 689/689 [==============================] - 7s 11ms/step - loss: 0.1699 - accuracy: 0.9347 - val_loss: 0.2272 - val_accuracy: 0.9192
# Epoch 86/100
# 689/689 [==============================] - 8s 11ms/step - loss: 0.1717 - accuracy: 0.9367 - val_loss: 0.2107 - val_accuracy: 0.9261
# Epoch 87/100
# 689/689 [==============================] - 7s 10ms/step - loss: 0.1746 - accuracy: 0.9326 - val_loss: 0.2231 - val_accuracy: 0.9181
# Epoch 88/100
# 689/689 [==============================] - 6s 9ms/step - loss: 0.1664 - accuracy: 0.9374 - val_loss: 0.2189 - val_accuracy: 0.9224
# Epoch 89/100
# 689/689 [==============================] - 7s 10ms/step - loss: 0.1672 - accuracy: 0.9368 - val_loss: 0.2144 - val_accuracy: 0.9215
# Epoch 90/100
# 689/689 [==============================] - 7s 10ms/step - loss: 0.1698 - accuracy: 0.9368 - val_loss: 0.2019 - val_accuracy: 0.9292
# Epoch 91/100
# 689/689 [==============================] - 7s 10ms/step - loss: 0.1674 - accuracy: 0.9371 - val_loss: 0.2188 - val_accuracy: 0.9217
# Epoch 92/100
# 689/689 [==============================] - 6s 9ms/step - loss: 0.1660 - accuracy: 0.9369 - val_loss: 0.2172 - val_accuracy: 0.9215
# Epoch 93/100
# 689/689 [==============================] - 7s 10ms/step - loss: 0.1682 - accuracy: 0.9366 - val_loss: 0.2349 - val_accuracy: 0.9145
# Epoch 94/100
# 689/689 [==============================] - 7s 10ms/step - loss: 0.1618 - accuracy: 0.9376 - val_loss: 0.2149 - val_accuracy: 0.9223
# Epoch 95/100
# 689/689 [==============================] - 6s 9ms/step - loss: 0.1668 - accuracy: 0.9373 - val_loss: 0.2359 - val_accuracy: 0.9145
# Epoch 96/100
# 689/689 [==============================] - 7s 10ms/step - loss: 0.1632 - accuracy: 0.9383 - val_loss: 0.2143 - val_accuracy: 0.9221
# Epoch 97/100
# 689/689 [==============================] - 7s 11ms/step - loss: 0.1679 - accuracy: 0.9366 - val_loss: 0.2031 - val_accuracy: 0.9286
# Epoch 98/100
# 689/689 [==============================] - 7s 11ms/step - loss: 0.1640 - accuracy: 0.9379 - val_loss: 0.2231 - val_accuracy: 0.9208
# Epoch 99/100
# 689/689 [==============================] - 7s 11ms/step - loss: 0.1612 - accuracy: 0.9386 - val_loss: 0.2159 - val_accuracy: 0.9252
# Epoch 100/100
# 689/689 [==============================] - 7s 10ms/step - loss: 0.1614 - accuracy: 0.9386 - val_loss: 0.2124 - val_accuracy: 0.9257

# %%
# summarize history for loss
def summarize_loss(history):
    plt.figure(figsize=(8,6))
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'validation'], loc='upper right')
    plt.show()

# %%
_, model_accuracy = model.evaluate(X_test, y_test, verbose=0)
print("Model Accuraccy: ", round(model_accuracy, 2))
summarize_loss(history)
# Out:
# Model Accuraccy:  0.9

# %%
def plot_conf_matrix(y_test, y_pred):
    plt.figure(figsize=(8,6))
    sns.heatmap(confusion_matrix(y_test,y_pred), cmap='Blues', annot=True, fmt='g');
    plt.title('Confusion Matrix')
    plt.xlabel("Predictions")
    plt.ylabel("Real values")
    plt.show()

# %%
X_test.shape
# Out:
# (6882, 60, 1)

# %%
y_test.shape
# Out:
# (6882,)

# %%
y_pred = model.predict(X_test)

# %%
y_pred = model.predict(X_test)
y_pred = y_pred > 0.5
print('\n\t\tECG - CNN V1 - MODEL EVALUATION\n')
print(classification_report(y_test, y_pred, target_names=['SR', 'AFIB']))
plot_conf_matrix(y_test, y_pred)
# Out:
# 		ECG - CNN V1 - MODEL EVALUATION
#
#               precision    recall  f1-score   support
#
#           SR       0.85      0.94      0.89      3083
#         AFIB       0.95      0.86      0.90      3799
#
#     accuracy                           0.90      6882
#    macro avg       0.90      0.90      0.90      6882
# weighted avg       0.90      0.90      0.90      6882

# %%
y_test[0]
# Out:
# 1.0

# %%
X_test.shape
# Out:
# (6882, 60, 1)

# %%
X_test[0].shape
# Out:
# (60, 1)

# %%
ecg_test = X_test[0]
ecg_test = ecg_test.reshape(1,60,1)
ecg_test.shape
# Out:
# (1, 60, 1)

# %%
ecg_pred = model.predict(ecg_test)
ecg_pred = ecg_pred > 0.5
ecg_pred = ecg_pred[0][0]
ecg_pred
# Out:
# True

# %%
for i in range (10):
    ecg_pred = model.predict(X_test[i].reshape(1,60,1))
    ecg_pred = ecg_pred > 0.5
    ecg_pred = ecg_pred[0][0]
    print(ecg_pred)
# Out:
# True
# False
# True
# False
# True
# False
# True
# False
# False
# True

# %%
y_test[:10]
# Out:
# array([1., 0., 1., 0., 1., 0., 1., 0., 0., 1.])

# %%
X_sr = X_sr - X_sr.min()
X_sr = X_sr/X_sr.max()

# %%
for i in range(20):
    ecg_pred = model.predict(X_sr[i].T.reshape(1,60,1))
    ecg_pred = ecg_pred > 0.5
    ecg_pred = ecg_pred[0][0]
    print(ecg_pred)
# Out:
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False

# %%
X_afib = X_afib - X_afib.min()
X_afib = X_afib/X_afib.max()

# %%
for i in range(20):
    ecg_pred = model.predict(X_afib[i].T.reshape(1,60,1))
    ecg_pred = ecg_pred > 0.5
    ecg_pred = ecg_pred[0][0]
    print(ecg_pred)
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True

# %% [markdown]
# ## Testing with real data

# %%
# !ls ../data/Real_Colected_data
# Out:
# ecg_data_boneco_afib_com_ruido.csv
# ecg_data_boneco_afib_sem_ruido.csv
# ecg_data_boneco_sr_com_ruido.csv
# ecg_data_boneco_sr_sem_ruido.csv
# ecg_homecare_data_10_s_100Hz_ADS1115.csv

# %% [markdown]
# ### Real person with no heart condition

# %%
df = pd.read_csv("ecg_homecare_data_10_s_100Hz_ADS1115.csv")
df.shape
# Out:
# (12965, 3)

# %%
df.head(2)
# Out:
#        time  Unnamed: 1  samples
# 0  15:56:57     57417.7       23
# 1  15:56:57     57417.7       36

# %%
X = df['samples'].values.astype('float32')
X.shape
# Out:
# (12965,)

# %%
plt.plot(X[:600])
plt.grid(color='r', linestyle=':', linewidth=0.5);

# %%
X
# Out:
# array([23., 36., 39., ..., 43., 42., 43.], dtype=float32)

# %%
X_sr = get_complete_Heartbit(X, sampling_rate=100, plot=False)
X_sr.shape
# Out:
# (163, 60)

# %%
X_sr.min(), X_sr.max()
# Out:
# (-859.5821127467997, 821.660371091236)

# %%
X_sr = X_sr - X_sr.min()
X_sr = X_sr/X_sr.max()
print (X_sr.min(), X_sr.max())
# Out:
# 0.0 1.0

# %%
for i in range(len(X_sr)):
    plt.plot(X_sr[i], color = 'r')
    plt.title("Raw HeartBits")
    plt.grid()

# %%
pred = []
for i in range (len(X_sr)):
    ecg_pred = model.predict(X_sr[i].reshape(1,60,1))
    ecg_pred = ecg_pred > 0.5
    ecg_pred = ecg_pred[0][0]
    pred.append(ecg_pred)

print ("Number of heartbeats classified as AFIB: ",np.asarray(pred).sum())
# Out:
# Number of heartbeats classified as AFIB:  27

# %% [markdown]
# ### Boneco with no heart condition and no noise

# %%
#df = pd.read_csv("ecg_data_boneco_sr_sem_ruido.csv")
df = pd.read_csv("ecg_data_boneco_sr_sem_ruido.csv")
X = df['values'].values.astype('float32')
print(X.shape)
plt.plot(X[:999])
plt.grid(color='r', linestyle=':', linewidth=0.5);
# Out:
# (3043,)

# %%
X_sr = get_complete_Heartbit(X, sampling_rate=100, plot=False)
print("Number of samples: ", X_sr.shape[0])
X_sr = X_sr - X_sr.min()
X_sr = X_sr/X_sr.max()

for i in range(len(X_sr)):
    plt.plot(X_sr[i], color = 'r')
    plt.title("Boneco with no heart condition and no noise - HeartBits")
    plt.grid()
# Out:
# Number of samples:  40

# %%
pred = []
for i in range (len(X_sr)):
    ecg_pred = model.predict(X_sr[i].reshape(1,60,1))
    ecg_pred = ecg_pred > 0.5
    ecg_pred = ecg_pred[0][0]
    pred.append(ecg_pred)

print ("Number of heartbeats classified as AFIB: ",np.asarray(pred).sum())
# Out:
# Number of heartbeats classified as AFIB:  0

# %% [markdown]
# ### Boneco with no heart condition and with noise

# %%
#df = pd.read_csv("../data//Real_Colected_data/ecg_data_boneco_sr_com_ruido.csv")
df = pd.read_csv("ecg_data_boneco_sr_com_ruido.csv")
X = df['values'].values.astype('float32')
print(X.shape)
plt.plot(X[:999])
plt.grid(color='r', linestyle=':', linewidth=0.5);
# Out:
# (3976,)

# %%
X_sr = get_complete_Heartbit(X, sampling_rate=100, plot=False)
print("Number of samples: ", X_sr.shape[0])
X_sr = X_sr - X_sr.min()
X_sr = X_sr/X_sr.max()

for i in range(len(X_sr)):
    plt.plot(X_sr[i], color = 'r')
    plt.title("Boneco with no heart condition and with noise - HeartBits")
    plt.grid()
# Out:
# Number of samples:  52

# %%
pred = []
for i in range (len(X_sr)):
    ecg_pred = model.predict(X_sr[i].reshape(1,60,1))
    ecg_pred = ecg_pred > 0.5
    ecg_pred = ecg_pred[0][0]
    pred.append(ecg_pred)

print ("Number of heartbeats classified as AFIB: ",np.asarray(pred).sum())
# Out:
# Number of heartbeats classified as AFIB:  0

# %% [markdown]
# ### Boneco with heart condition (AFIB) and no noise

# %%
#df = pd.read_csv("../data//Real_Colected_data/ecg_data_boneco_afib_sem_ruido.csv")
df = pd.read_csv("ecg_data_boneco_afib_sem_ruido.csv")
X = df['values'].values.astype('float32')
print(X.shape)
plt.plot(X[:999])
plt.grid(color='r', linestyle=':', linewidth=0.5);
# Out:
# (8518,)

# %%
X_afib = get_complete_Heartbit(X, sampling_rate=100, plot=False)
print("Number of samples: ", X_afib.shape[0])
X_afib = X_afib - X_afib.min()
X_afib = X_afib/X_afib.max()

for i in range(len(X_afib)):
    plt.plot(X_afib[i], color = 'r')
    plt.title("Boneco with heart condition (AFIB) and no noise - HeartBits")
    plt.grid()
# Out:
# Number of samples:  138

# %%
teste = X_afib[0]
teste.shape
# Out:
# (60,)

# %%
plt.plot(teste);

# %%
ecg_pred = model.predict(X_afib[0].reshape(1,60,1))
ecg_pred
# Out:
# array([[6.5585436e-06]], dtype=float32)

# %%
pred = []
for i in range (len(X_afib)):
    ecg_pred = model.predict(X_afib[i].reshape(1,60,1))
    ecg_pred = ecg_pred > 0.5
    ecg_pred = ecg_pred[0][0]
    pred.append(ecg_pred)

print ("Number of heartbeats classified as AFIB: ",np.asarray(pred).sum())
# Out:
# Number of heartbeats classified as AFIB:  12

# %% [markdown]
# ## Boneco with heart condition (AFIB) and with noise

# %%
#df = pd.read_csv("../data//Real_Colected_data/ecg_data_boneco_afib_sem_ruido.csv")
df = pd.read_csv("ecg_data_boneco_afib_com_ruido.csv")
X = df['values'].values.astype('float32')
print(X.shape)
plt.plot(X[:999])
plt.grid(color='r', linestyle=':', linewidth=0.5);
# Out:
# (9068,)

# %%
X_afib = get_complete_Heartbit(X, sampling_rate=100, plot=False)
print("Number of samples: ", X_afib.shape[0])
X_afib = X_afib - X_afib.min()
X_afib = X_afib/X_afib.max()

for i in range(len(X_afib)):
    plt.plot(X_afib[i], color = 'r')
    plt.title("Boneco with heart condition (AFIB) and no noise - HeartBits")
    plt.grid()
# Out:
# Number of samples:  107

# %%
pred = []
for i in range (len(X_afib)):
    ecg_pred = model.predict(X_afib[i].reshape(1,60,1))
    ecg_pred = ecg_pred > 0.5
    ecg_pred = ecg_pred[0][0]
    pred.append(ecg_pred)

print ("Number of heartbeats classified as AFIB: ",np.asarray(pred).sum())
# Out:
# Number of heartbeats classified as AFIB:  55
