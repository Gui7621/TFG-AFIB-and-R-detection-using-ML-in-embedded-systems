# %%
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.signal import butter, iirnotch, sosfilt, sosfreqz, lfilter, filtfilt
import biosppy

import tensorflow as tf
from tensorflow.keras import Sequential,utils
from tensorflow.keras.layers import Input, Flatten, Dense, Conv1D, MaxPooling1D, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, LearningRateScheduler
from tensorflow.keras.models import load_model

from sklearn.utils import resample
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

plt.rcParams["figure.figsize"] = (10,5)

# %%
def butter_highpass(cutoff, sample_rate, order, data):
    nyq = 0.5 * sample_rate
    normal_cutoff = cutoff / nyq
    b, a = butter(order, normal_cutoff, btype='high', analog=False)
    final_filtered_highpass = filtfilt(b, a, data)
    return final_filtered_highpass


def butter_lowpass(cutoff, sample_rate, order, data, slice=-1):
    nyq = 0.5 * sample_rate
    normal_cutoff = cutoff / nyq
    b, a = butter(order, normal_cutoff, btype='low', analog=False)
    filtered_lowpass = lfilter(b, a, data)
    return filtered_lowpass


def moving_average_filter(x, w):
    m_a_filtered = np.convolve(x, np.ones(w), 'same') / w
    return m_a_filtered


def filter_data(data, sample_rate=100):
    filtered_data_low = butter_lowpass(41.09, sample_rate, 5, data)
    filtered_data_high = butter_highpass(0.48, sample_rate, 2, filtered_data_low)
    #final_filtered_data = moving_average_filter(filtered_data_high, 3)
    return filtered_data_high

# %%
def plot_conf_matrix(y_test, y_pred):
    plt.figure(figsize=(8,6))
    sns.heatmap(confusion_matrix(y_test,y_pred), cmap='Blues', annot=True, fmt='g');
    plt.title('Confusion Matrix')
    plt.xlabel("Predictions")
    plt.ylabel("Real values")
    plt.show()

# %%
df = pd.read_csv("ECG_Rhythm_Lead_I.csv")
del df["Unnamed: 0"]
df.shape
# Out:
# (21837, 1006)

# %%
df.head()
# Out:
#    ecg_id   age  sex  height  weight rhythm_diag      0      1      2      3  \
# 0       1  56.0    1     NaN    63.0          SR -0.119 -0.116 -0.120 -0.117
# 1       2  19.0    0     NaN    70.0       OTHER  0.004 -0.020 -0.053 -0.056
# 2       3  37.0    1     NaN    69.0          SR -0.029 -0.035 -0.054 -0.078
# 3       4  24.0    0     NaN    82.0          SR -0.054 -0.053 -0.063 -0.060
# 4       5  19.0    1     NaN    70.0          SR -0.034 -0.038 -0.057 -0.066
#
#    ...    990    991    992    993    994    995    996    997    998    999
# 0  ...  0.198  0.194  0.115  0.107  0.107  0.106  0.090  0.069  0.086  0.022
# 1  ... -0.035 -0.045  0.004  0.044  0.507  0.554  0.316  0.121 -0.326 -0.348
# 2  ... -0.040 -0.051 -0.026 -0.032 -0.052 -0.039 -0.034 -0.029 -0.048 -0.049
# 3  ... -0.312 -0.511 -0.280 -0.076 -0.012  0.001 -0.003  0.026  0.026  0.028
# 4  ...  0.005  0.001  0.003  0.013  0.018 -0.001  0.007  0.000 -0.003 -0.012
#
# [5 rows x 1006 columns]

# %%
df['rhythm_diag'] = df['rhythm_diag'].map(dict(OTHER=2,AFIB=1, SR=0))
df.rhythm_diag.value_counts()
# Out:
# 0    16782
# 2     3541
# 1     1514
# Name: rhythm_diag, dtype: int64

# %%
df_minority = df[df['rhythm_diag']==1]
df_majority_SR = df[df['rhythm_diag']==0]
df_majority_OTHER = df[df['rhythm_diag']==2]
maj_class_SR = resample(df_majority_SR,
                         replace=True,
                         n_samples=1514,
                         random_state=123)
maj_class_OTHER = resample(df_majority_OTHER,
                             replace=True,
                             n_samples=1514,
                             random_state=123)
df=pd.concat([df_minority,maj_class_SR,maj_class_OTHER])

# %%
df.rhythm_diag.value_counts()
# Out:
# 0    1514
# 1    1514
# 2    1514
# Name: rhythm_diag, dtype: int64

# %%
df_sr = df[df.rhythm_diag == 0]
df_sr = df_sr.drop(['ecg_id', 'age', 'sex', 'height',
                    'weight', 'rhythm_diag'], axis=1)
df_sr.reset_index(drop= True ,inplace=True)
df_sr.shape
# Out:
# (1514, 1000)

# %%
df_afib = df[df.rhythm_diag == 1]
df_afib = df_afib.drop(
    ['ecg_id', 'age', 'sex', 'height', 'weight', 'rhythm_diag'], axis=1)
df_afib.reset_index(drop=True, inplace=True)
df_afib.shape
# Out:
# (1514, 1000)

# %%
df_other = df[df.rhythm_diag == 2]
df_other = df_other.drop(
    ['ecg_id', 'age', 'sex', 'height', 'weight', 'rhythm_diag'], axis=1)
df_other.reset_index(drop=True, inplace=True)
df_other.shape
# Out:
# (1514, 1000)

# %%
X_sr = df_sr.values
X_afib = df_afib.values
X_other = df_other.values

# %% [markdown]
# ### Get individuals HeartBeats

# %%
def maior_valor_sinal(sinal):
    maior_valor = 0
    for i in range(len(sinal)):
        if(sinal[i] > maior_valor):
            maior_valor = sinal[i]
    return maior_valor

# %%
def R_peak_detection(sinal):
    sinal = filter_data(sinal,100)
    indice_aux = 0
    indice_maximo = []
    valor_aux = 0
    valor_maximo = []
    flag_contagem = 0
    indice_temp = 0
    valor_temp = 0
    i = 0
    valor_referencia = maior_valor_sinal(sinal)*0.5
    #print(valor_referencia)
    while i < len(sinal):
        if(sinal[i] > (valor_referencia)):
            indice_aux = i;
            valor_aux = sinal[i];
            if((indice_aux + 5) > len(sinal)):
                pass
            else:
                for x in range(5):
                    if(sinal[indice_aux+x] > valor_aux):
                        indice_temp = indice_aux + x
                        valor_temp = sinal[indice_aux + x]
                        valor_aux = sinal[indice_aux+x]
                    else:
                        flag_contagem = flag_contagem + 1
                indice_maximo.append(indice_temp) 
                valor_maximo.append(valor_temp) 
                if(flag_contagem == 5):
                    indice_maximo.append(i) 
                    valor_maximo.append(sinal[i]) 
                flag_contagem = 0
                indice_temp = 0
                valor_temp = 0
                indice_aux = 0
                valor_aux = 0
                #print(indice_temp+i)
                #print(indice_maximo)
                i = i + 30
        i = i + 1
    contador_zeros = 0
    for j in range (len(indice_maximo)):
        if(indice_maximo[j] == 0):
            contador_zeros = contador_zeros + 1
    for k in range (len(indice_maximo) - contador_zeros):
        if(indice_maximo[k] == 0):
            indice_maximo = np.delete(indice_maximo, k)
    return indice_maximo

# %%
def Get_Heartbeats(sinal, frequencia_amostragem, plot = True):
    picos_R = R_peak_detection(sinal)
    heartbeats = []
    indice_min = 0
    indice_max = 0
    zero_points_after = 0
    zero_points_before = 0
    zero_points_aux = 0
    zero_points_aux_1 = 0
    zero_points_aux_2 = 0
    hb = []
    tamanho_sinal = len(sinal)
    tamanho_picos = len(picos_R)-1
    for i in range(1,tamanho_picos):
        difference_peaks_before = picos_R[i]-picos_R[i-1]
        difference_peaks_after = picos_R[i+1]-picos_R[i]
        if((difference_peaks_before >= 25) and (difference_peaks_after >= 35)):
            indice_min = picos_R[i] - (0.25*frequencia_amostragem)
            indice_max = picos_R[i] + (0.35*frequencia_amostragem)
            heartbeats.append(sinal[int(indice_min):int(indice_max)])
        elif((difference_peaks_before) >= 25 and (difference_peaks_after < 35)):
            zero_points_after = 35 - int(difference_peaks_after/2)
            zero_points_aux = np.zeros(zero_points_after)
            indice_min = picos_R[i] - (0.25*frequencia_amostragem)
            indice_max = picos_R[i] + int(difference_peaks_after/2)
            heartbeats.append(np.concatenate((sinal[int(indice_min):int(indice_max)],zero_points_aux), axis=None))
        elif((difference_peaks_before < 25) and (difference_peaks_after >= 35)):
            zero_points_before = 25 - int(difference_peaks_before/2)
            zero_points_aux = np.zeros(zero_points_before)
            indice_min = picos_R[i] - int(difference_peaks_before/2)
            indice_max = picos_R[i] + (0.35*frequencia_amostragem) 
            heartbeats.append(np.concatenate((zero_points_aux, sinal[int(indice_min):int(indice_max)]), axis=None))
        elif((difference_peaks_before < 25) and (difference_peaks_after < 35)):
            zero_points_before = 25 - int(difference_peaks_before/2)
            zero_points_after = 35 - int(difference_peaks_after/2)
            zero_points_aux_1 = np.zeros(zero_points_before)
            zero_points_aux_2 = np.zeros(zero_points_after)
            indice_min = picos_R[i] - int(difference_peaks_before/2)
            indice_max = picos_R[i] + int(difference_peaks_after/2)
            heartbeats.append(np.concatenate((zero_points_aux_1, sinal[int(indice_min):int(indice_max)], zero_points_aux_2), axis=None))
    heartbeats = np.array(heartbeats)
    #print(heartbeats.shape)
    if plot:
        for j in range(len(heartbeats)):
            plt.plot(heartbeats[j])
    return heartbeats

# %%
def Get_Complete_Heartbeats(sinal, frequencia_amostragem, plot = True):
    templates = []
    templates_aux = []
    hb = []
    hb_aux = []
    for i in range(len(sinal)): 
        hb_aux = Get_Heartbeats(sinal[i], 100, False)
        for j in range(len(hb_aux)):
            hb.append(hb_aux[j])
    return np.array(hb)

# %%
X_sr = Get_Complete_Heartbeats(X_sr, 100, plot = False)
X_sr.shape
# Out:
# (14965, 60)

# %%
y_sr = []
y_sr_content = [0,1,0]
for i in range(len(X_sr)):
    y_sr.append(y_sr_content)
y_sr = np.array(y_sr)
y_sr.shape
# Out:
# (14965, 3)

# %%
X_afib = Get_Complete_Heartbeats(X_afib, 100, plot = False)
X_afib.shape
# Out:
# (18567, 60)

# %%
y_afib = []
y_afib_content = [0,0,1]
for i in range(len(X_afib)):
    y_afib.append(y_afib_content)
y_afib = np.array(y_afib)
y_afib.shape
# Out:
# (18567, 3)

# %%
X_other = Get_Complete_Heartbeats(X_other, 100, plot = False)
X_other.shape
# Out:
# (16186, 60)

# %%
y_other = []
y_other_content = [1,0,0]
for i in range(len(X_other)):
    y_other.append(y_other_content)
y_other = np.array(y_other)
y_other.shape
# Out:
# (16186, 3)

# %%
for i in range(100):
    plt.plot(X_sr[i])

# %%
for i in range(100):
    plt.plot(X_afib[i])

# %%
for i in range(100):
    plt.plot(X_other[i])

# %%
X = np.concatenate((X_other, X_sr, X_afib), axis=0)
X.shape
# Out:
# (49718, 60)

# %%
y = np.concatenate((y_other, y_sr, y_afib), axis=0)
y.shape
# Out:
# (49718, 3)

# %%
#saving data
from numpy import save
save('X_07_09.npy', X)
save('y_07_09.npy', y)

# %%
from numpy import load
# Getting data

X = load('X_07_09.npy')
y = load('y_07_09.npy')

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,
                                                    test_size=0.20,
                                                    random_state=21)

# %%
def normalize_data(Xt):
    Xt_full = []
    for i in range(len(Xt)):
        norm = ((Xt[i] - Xt[i].min())/(Xt[i].max() - Xt[i].min()))
        Xt_full.append(norm)

    Xt_full = np.array(Xt_full)
    print(Xt_full.shape)
    return Xt_full

# %%
print (X_train.min(), X_train.max())
X_train = normalize_data(X_train)
print (X_train.min(), X_train.max())
# Out:
# -4.729 2.713
# (39774, 60)
# 0.0 1.0

# %%
print (X_test.min(), X_test.max())
X_test = normalize_data(X_test)
print (X_test.min(), X_test.max())
# Out:
# -1.84 3.156
# (9944, 60)
# 0.0 1.0

# %%
X_train = np.expand_dims(X_train, 2)
X_test = np.expand_dims(X_test, 2)

print(X_train.shape, X_test.shape)
# Out:
# (39774, 60, 1) (9944, 60, 1)

# %%
samples, features, depht = X_train.shape
print(samples, features, depht)
# Out:
# 39774 60 1

# %%
import tensorflow as tf
from tensorflow.keras import Sequential,utils
from tensorflow.keras.layers import Input, Flatten, Dense, Conv1D, MaxPooling1D, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, LearningRateScheduler
from tensorflow.keras.models import load_model

from sklearn.utils import resample
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

# %%
def group_layer(model):
    model.add(
        Conv1D(32,
               kernel_size=5,
               strides=1,
               padding='same',
               activation='relu'))
    model.add(
        Conv1D(32,
               kernel_size=5,
               strides=1,
               padding='same',
               activation='relu'))
    model.add(MaxPooling1D(pool_size=5, strides=2))
    return model

# %%
model = Sequential()
model.add(Input(shape=(features, depht)))
model=group_layer(model)
model.add(Dropout(0.2))
model=group_layer(model)
model.add(Dropout(0.2))
model=group_layer(model)
model.add(Dropout(0.2))
model.add(Flatten())
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(3, activation='softmax'))
# Out:
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_12 (Conv1D)           (None, 60, 32)            192
# _________________________________________________________________
# conv1d_13 (Conv1D)           (None, 60, 32)            5152
# _________________________________________________________________
# max_pooling1d_6 (MaxPooling1 (None, 28, 32)            0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 28, 32)            0
# _________________________________________________________________
# conv1d_14 (Conv1D)           (None, 28, 32)            5152
# _________________________________________________________________
# conv1d_15 (Conv1D)           (None, 28, 32)            5152
# _________________________________________________________________
# max_pooling1d_7 (MaxPooling1 (None, 12, 32)            0
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 12, 32)            0
# _________________________________________________________________
# conv1d_16 (Conv1D)           (None, 12, 32)            5152
# _________________________________________________________________
# conv1d_17 (Conv1D)           (None, 12, 32)            5152
# _________________________________________________________________
# max_pooling1d_8 (MaxPooling1 (None, 4, 32)             0
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 4, 32)             0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 128)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 32)                4128
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_7 (Dense)              (None, 32)                1056
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_8 (Dense)              (None, 3)                 99
# =================================================================
# Total params: 31,235
# Trainable params: 31,235
# Non-trainable params: 0
# _________________________________________________________________

# %%
opt = Adam(beta_1=0.9, beta_2=0.999)
model.compile(loss='categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])

# %%
early_stop = EarlyStopping(monitor='val_loss', 
                           mode='min', 
                           verbose=1, 
                           patience=10)

# %%
EPOCHS = 50

history = model.fit(X_train,
                    y_train,
                    epochs=EPOCHS,
                    validation_split=0.2,
                    verbose=1,
                    callbacks=[early_stop])
# Out:
# Epoch 1/50
# 995/995 [==============================] - 11s 10ms/step - loss: 0.9558 - accuracy: 0.5063 - val_loss: 0.8138 - val_accuracy: 0.6005
# Epoch 2/50
# 995/995 [==============================] - 10s 10ms/step - loss: 0.8306 - accuracy: 0.6072 - val_loss: 0.7721 - val_accuracy: 0.6401
# Epoch 3/50
# 995/995 [==============================] - 10s 10ms/step - loss: 0.7924 - accuracy: 0.6347 - val_loss: 0.8009 - val_accuracy: 0.6263
# Epoch 4/50
# 995/995 [==============================] - 10s 10ms/step - loss: 0.7825 - accuracy: 0.6402 - val_loss: 0.7619 - val_accuracy: 0.6532
# Epoch 5/50
# 995/995 [==============================] - 10s 10ms/step - loss: 0.7697 - accuracy: 0.6453 - val_loss: 0.7302 - val_accuracy: 0.6694
# Epoch 6/50
# 995/995 [==============================] - 10s 10ms/step - loss: 0.7580 - accuracy: 0.6544 - val_loss: 0.7418 - val_accuracy: 0.6603
# Epoch 7/50
# 995/995 [==============================] - 10s 10ms/step - loss: 0.7491 - accuracy: 0.6594 - val_loss: 0.7220 - val_accuracy: 0.6665
# Epoch 8/50
# 995/995 [==============================] - 11s 11ms/step - loss: 0.7461 - accuracy: 0.6611 - val_loss: 0.7195 - val_accuracy: 0.6664
# Epoch 9/50
# 995/995 [==============================] - 11s 11ms/step - loss: 0.7376 - accuracy: 0.6658 - val_loss: 0.7137 - val_accuracy: 0.6734
# Epoch 10/50
# 995/995 [==============================] - 9s 9ms/step - loss: 0.7329 - accuracy: 0.6687 - val_loss: 0.7081 - val_accuracy: 0.6784
# Epoch 11/50
# 995/995 [==============================] - 9s 9ms/step - loss: 0.7270 - accuracy: 0.6716 - val_loss: 0.7264 - val_accuracy: 0.6661
# Epoch 12/50
# 995/995 [==============================] - 9s 9ms/step - loss: 0.7224 - accuracy: 0.6749 - val_loss: 0.7059 - val_accuracy: 0.6788
# Epoch 13/50
# 995/995 [==============================] - 9s 9ms/step - loss: 0.7176 - accuracy: 0.6769 - val_loss: 0.7030 - val_accuracy: 0.6822
# Epoch 14/50
# 995/995 [==============================] - 9s 9ms/step - loss: 0.7155 - accuracy: 0.6790 - val_loss: 0.6975 - val_accuracy: 0.6867
# Epoch 15/50
# 995/995 [==============================] - 10s 10ms/step - loss: 0.7137 - accuracy: 0.6787 - val_loss: 0.6914 - val_accuracy: 0.6875
# Epoch 16/50
# 995/995 [==============================] - 10s 10ms/step - loss: 0.7072 - accuracy: 0.6855 - val_loss: 0.6873 - val_accuracy: 0.6895 0.7075 - accu
# Epoch 17/50
# 995/995 [==============================] - 9s 9ms/step - loss: 0.7043 - accuracy: 0.6829 - val_loss: 0.6949 - val_accuracy: 0.6869
# Epoch 18/50
# 995/995 [==============================] - 9s 9ms/step - loss: 0.7016 - accuracy: 0.6831 - val_loss: 0.6888 - val_accuracy: 0.6899
# Epoch 19/50
# 995/995 [==============================] - 9s 9ms/step - loss: 0.7002 - accuracy: 0.6871 - val_loss: 0.6791 - val_accuracy: 0.6965
# Epoch 20/50
# 995/995 [==============================] - 9s 9ms/step - loss: 0.6968 - accuracy: 0.6890 - val_loss: 0.6871 - val_accuracy: 0.6874
# Epoch 21/50
# 995/995 [==============================] - 9s 9ms/step - loss: 0.6948 - accuracy: 0.6882 - val_loss: 0.6784 - val_accuracy: 0.6920
# Epoch 22/50
# 995/995 [==============================] - 10s 10ms/step - loss: 0.6892 - accuracy: 0.6913 - val_loss: 0.6826 - val_accuracy: 0.6968
# Epoch 23/50
# 995/995 [==============================] - 10s 10ms/step - loss: 0.6895 - accuracy: 0.6924 - val_loss: 0.6723 - val_accuracy: 0.6992
# Epoch 24/50
# 995/995 [==============================] - 10s 10ms/step - loss: 0.6856 - accuracy: 0.6956 - val_loss: 0.6798 - val_accuracy: 0.6864
# Epoch 25/50
# 995/995 [==============================] - 10s 10ms/step - loss: 0.6858 - accuracy: 0.6926 - val_loss: 0.6782 - val_accuracy: 0.6963
# Epoch 26/50
# 995/995 [==============================] - 11s 11ms/step - loss: 0.6797 - accuracy: 0.6942 - val_loss: 0.6807 - val_accuracy: 0.6962
# Epoch 27/50
# 995/995 [==============================] - 10s 10ms/step - loss: 0.6795 - accuracy: 0.6983 - val_loss: 0.6655 - val_accuracy: 0.7009
# Epoch 28/50
# 995/995 [==============================] - 9s 9ms/step - loss: 0.6767 - accuracy: 0.6985 - val_loss: 0.6613 - val_accuracy: 0.7056
# Epoch 29/50
# 995/995 [==============================] - 9s 9ms/step - loss: 0.6761 - accuracy: 0.6996 - val_loss: 0.6683 - val_accuracy: 0.7043
# Epoch 30/50
# 995/995 [==============================] - 9s 9ms/step - loss: 0.6775 - accuracy: 0.6987 - val_loss: 0.6639 - val_accuracy: 0.7063
# Epoch 31/50
# 995/995 [==============================] - 9s 9ms/step - loss: 0.6720 - accuracy: 0.7019 - val_loss: 0.6677 - val_accuracy: 0.7056
# Epoch 32/50
# 995/995 [==============================] - 10s 11ms/step - loss: 0.6730 - accuracy: 0.7028 - val_loss: 0.6695 - val_accuracy: 0.7017
# Epoch 33/50
# 995/995 [==============================] - 10s 11ms/step - loss: 0.6671 - accuracy: 0.7037 - val_loss: 0.6553 - val_accuracy: 0.7077
# Epoch 34/50
# 995/995 [==============================] - 11s 12ms/step - loss: 0.6650 - accuracy: 0.7068 - val_loss: 0.6716 - val_accuracy: 0.7002
# Epoch 35/50
# 995/995 [==============================] - 10s 10ms/step - loss: 0.6608 - accuracy: 0.7090 - val_loss: 0.6538 - val_accuracy: 0.7094
# Epoch 36/50
# 995/995 [==============================] - 9s 9ms/step - loss: 0.6663 - accuracy: 0.7061 - val_loss: 0.6618 - val_accuracy: 0.7046
# Epoch 37/50
# 995/995 [==============================] - 11s 11ms/step - loss: 0.6635 - accuracy: 0.7078 - val_loss: 0.6590 - val_accuracy: 0.7036
# Epoch 38/50
# 995/995 [==============================] - 11s 11ms/step - loss: 0.6587 - accuracy: 0.7085 - val_loss: 0.6535 - val_accuracy: 0.7091
# Epoch 39/50
# 995/995 [==============================] - 10s 10ms/step - loss: 0.6592 - accuracy: 0.7099 - val_loss: 0.6508 - val_accuracy: 0.7107
# Epoch 40/50
# 995/995 [==============================] - 9s 9ms/step - loss: 0.6559 - accuracy: 0.7108 - val_loss: 0.6455 - val_accuracy: 0.7131
# Epoch 41/50
# 995/995 [==============================] - 9s 9ms/step - loss: 0.6545 - accuracy: 0.7106 - val_loss: 0.6484 - val_accuracy: 0.7163
# Epoch 42/50
# 995/995 [==============================] - 9s 9ms/step - loss: 0.6565 - accuracy: 0.7106 - val_loss: 0.6469 - val_accuracy: 0.7085
# Epoch 43/50
# 995/995 [==============================] - 9s 9ms/step - loss: 0.6512 - accuracy: 0.7103 - val_loss: 0.6412 - val_accuracy: 0.7188
# Epoch 44/50
# 995/995 [==============================] - 10s 10ms/step - loss: 0.6528 - accuracy: 0.7118 - val_loss: 0.6410 - val_accuracy: 0.7163
# Epoch 45/50
# 995/995 [==============================] - 10s 10ms/step - loss: 0.6498 - accuracy: 0.7123 - val_loss: 0.6474 - val_accuracy: 0.7145
# Epoch 46/50
# 995/995 [==============================] - 9s 9ms/step - loss: 0.6490 - accuracy: 0.7138 - val_loss: 0.6462 - val_accuracy: 0.7111
# Epoch 47/50
# 995/995 [==============================] - 9s 9ms/step - loss: 0.6459 - accuracy: 0.7128 - val_loss: 0.6473 - val_accuracy: 0.7113
# Epoch 48/50
# 995/995 [==============================] - 11s 11ms/step - loss: 0.6481 - accuracy: 0.7125 - val_loss: 0.6354 - val_accuracy: 0.7198
# Epoch 49/50
# 995/995 [==============================] - 9s 9ms/step - loss: 0.6459 - accuracy: 0.7160 - val_loss: 0.6412 - val_accuracy: 0.7172
# Epoch 50/50
# 995/995 [==============================] - 9s 9ms/step - loss: 0.6457 - accuracy: 0.7153 - val_loss: 0.6402 - val_accuracy: 0.7118

# %%
# summarize history for loss
def summarize_loss(history):
    plt.figure(figsize=(8,6))
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'validation'], loc='upper right')
    plt.show()

# %%
_, model_accuracy = model.evaluate(X_test, y_test, verbose=0)
print("Model Accuraccy: ", round(model_accuracy, 2))
summarize_loss(history)
# Out:
# Model Accuraccy:  0.71

# %%
def plot_conf_matrix(y_test, y_pred):
    plt.figure(figsize=(8,6))
    sns.heatmap(confusion_matrix(y_test,y_pred), cmap='Blues', annot=True, fmt='g');
    plt.title('Confusion Matrix')
    plt.xlabel("Predictions")
    plt.ylabel("Real values")
    plt.show()

# %%
y_pred = model.predict(X_test)

# %%
y_pred = y_pred > 0.60

# %%
indice_2 = []
for i in range(len(y_pred)):
    indice_2.append(np.argmax(y_pred[i]))
indice_2 = np.array(indice_2)
print(indice_2.shape)
indice_2[0:20]
# Out:
# (9944,)
# array([2, 0, 0, 0, 0, 2, 2, 0, 0, 0, 0, 2, 0, 0, 2, 0, 0, 0, 0, 0],
#       dtype=int64)

# %%
def plot_conf_matrix(y_test, y_pred):
    plt.figure(figsize=(8,6))
    sns.heatmap(confusion_matrix(y_test.argmax(axis=1), y_pred.argmax(axis=1)), cmap='Blues', annot=True, fmt='g');
    plt.title('Confusion Matrix')
    plt.xlabel("Predictions")
    plt.ylabel("Real values")
    plt.show()

# %%
print('\n\t\tECG - CNN V1 - MODEL EVALUATION\n')
print(classification_report(y_test, y_pred, target_names=['OTHER','SR', 'AFIB']))
plot_conf_matrix(y_test, y_pred)
# Out:
# 		ECG - CNN V1 - MODEL EVALUATION
#
#               precision    recall  f1-score   support
#
#        OTHER       0.80      0.34      0.47      3237
#           SR       0.69      0.57      0.63      2935
#         AFIB       0.87      0.76      0.81      3772
#
#    micro avg       0.79      0.57      0.66      9944
#    macro avg       0.78      0.56      0.64      9944
# weighted avg       0.79      0.57      0.65      9944
#  samples avg       0.57      0.57      0.57      9944
# c:\python38\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### Model using the original way to get the heartbeats with 100 points

# %%
def Get_Heartbeats_2(sinal, frequencia_amostragem, plot = True):
    picos_R = R_peak_detection(sinal)
    heartbeats = []
    indice_min = 0
    indice_max = 0
    tamanho_sinal = len(sinal)
    for i in range(len(picos_R)):
        indice_min = picos_R[i] - (0.4*frequencia_amostragem)
        indice_max = picos_R[i] + (0.6*frequencia_amostragem)
        if((indice_min > 0) & (indice_max < tamanho_sinal)):
            heartbeats.append(sinal[int(indice_min):int(indice_max)])
    heartbeats = np.array(heartbeats)
    #print(heartbeats.shape)
    if plot:
        for j in range(len(heartbeats)):
            plt.plot(heartbeats[j])
    return heartbeats

# %%
def Get_Complete_Heartbeats_2(sinal, frequencia_amostragem, plot = True):
    templates = []
    templates_aux = []
    hb = []
    hb_aux = []
    for i in range(len(sinal)): 
        hb_aux = Get_Heartbeats_2(sinal[i], 100, False)
        for j in range(len(hb_aux)):
            hb.append(hb_aux[j])
    return np.array(hb)

# %%
X_sr = df_sr.values
X_afib = df_afib.values
X_other = df_other.values

# %%
X_sr = Get_Complete_Heartbeats_2(X_sr, 100, plot = False)
X_sr.shape
# Out:
# (16228, 100)

# %%
y_sr = []
y_sr_content = [1,0,0]
for i in range(len(X_sr)):
    y_sr.append(y_sr_content)
y_sr = np.array(y_sr)
y_sr.shape
# Out:
# (16228, 3)

# %%
X_afib = Get_Complete_Heartbeats_2(X_afib, 100, plot = False)
X_afib.shape
# Out:
# (19452, 100)

# %%
y_afib = []
y_afib_content = [0,1,0]
for i in range(len(X_afib)):
    y_afib.append(y_afib_content)
y_afib = np.array(y_afib)
y_afib.shape
# Out:
# (19452, 3)

# %%
X_other = Get_Complete_Heartbeats_2(X_other, 100, plot = False)
X_other.shape
# Out:
# (17307, 100)

# %%
y_other = []
y_other_content = [0,0,1]
for i in range(len(X_other)):
    y_other.append(y_other_content)
y_other = np.array(y_other)
y_other.shape
# Out:
# (17307, 3)

# %%
for i in range(100):
    plt.plot(X_sr[i])

# %%
for i in range(100):
    plt.plot(X_afib[i])

# %%
for i in range(100):
    plt.plot(X_other[i])

# %%
X = np.concatenate((X_sr, X_afib, X_other), axis=0)
X.shape
# Out:
# (52987, 100)

# %%
y = np.concatenate((y_sr, y_afib, y_other), axis=0)
y.shape
# Out:
# (52987, 3)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,
                                                    test_size=0.20,
                                                    random_state=21)

# %%
print (X_train.min(), X_train.max())
X_train = normalize_data(X_train)
print (X_train.min(), X_train.max())
# Out:
# -4.729 3.156
# (42389, 100)
# 0.0 1.0

# %%
print (X_test.min(), X_test.max())
X_test = normalize_data(X_test)
print (X_test.min(), X_test.max())
# Out:
# -2.357 4.398
# (10598, 100)
# 0.0 1.0

# %%
X_train = np.expand_dims(X_train, 2)
X_test = np.expand_dims(X_test, 2)

# %%
print(X_train.shape, X_test.shape)
# Out:
# (42389, 100, 1) (10598, 100, 1)

# %%
samples, features, depht = X_train.shape
print(samples, features, depht)
# Out:
# 42389 100 1

# %%
model = Sequential()
model.add(Input(shape=(features, depht)))
model=group_layer(model)
model.add(Dropout(0.2))
model=group_layer(model)
model.add(Dropout(0.2))
model=group_layer(model)
model.add(Dropout(0.2))
model.add(Flatten())
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(3, activation='softmax'))
# Out:
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_18 (Conv1D)           (None, 100, 32)           192
# _________________________________________________________________
# conv1d_19 (Conv1D)           (None, 100, 32)           5152
# _________________________________________________________________
# max_pooling1d_9 (MaxPooling1 (None, 48, 32)            0
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 48, 32)            0
# _________________________________________________________________
# conv1d_20 (Conv1D)           (None, 48, 32)            5152
# _________________________________________________________________
# conv1d_21 (Conv1D)           (None, 48, 32)            5152
# _________________________________________________________________
# max_pooling1d_10 (MaxPooling (None, 22, 32)            0
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 22, 32)            0
# _________________________________________________________________
# conv1d_22 (Conv1D)           (None, 22, 32)            5152
# _________________________________________________________________
# conv1d_23 (Conv1D)           (None, 22, 32)            5152
# _________________________________________________________________
# max_pooling1d_11 (MaxPooling (None, 9, 32)             0
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 9, 32)             0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 288)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 32)                9248
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_10 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_11 (Dense)             (None, 3)                 99
# =================================================================
# Total params: 36,355
# Trainable params: 36,355
# Non-trainable params: 0
# _________________________________________________________________

# %%
opt = Adam(beta_1=0.9, beta_2=0.999)
model.compile(loss='categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])

# %%
EPOCHS = 100

history = model.fit(X_train,
                    y_train,
                    epochs=EPOCHS,
                    validation_split=0.2,
                    verbose=1,
                    callbacks=[early_stop])
# Out:
# Epoch 1/100
# 1060/1060 [==============================] - 19s 17ms/step - loss: 0.8894 - accuracy: 0.5647 - val_loss: 0.6800 - val_accuracy: 0.6975
# Epoch 2/100
# 1060/1060 [==============================] - 17s 16ms/step - loss: 0.7159 - accuracy: 0.6862 - val_loss: 0.6556 - val_accuracy: 0.7143
# Epoch 3/100
# 1060/1060 [==============================] - 17s 16ms/step - loss: 0.6858 - accuracy: 0.7018 - val_loss: 0.6236 - val_accuracy: 0.7295
# Epoch 4/100
# 1060/1060 [==============================] - 15s 15ms/step - loss: 0.6708 - accuracy: 0.7109 - val_loss: 0.6068 - val_accuracy: 0.7350
# Epoch 5/100
# 1060/1060 [==============================] - 17s 16ms/step - loss: 0.6574 - accuracy: 0.7173 - val_loss: 0.6025 - val_accuracy: 0.7396
# Epoch 6/100
# 1060/1060 [==============================] - 17s 16ms/step - loss: 0.6450 - accuracy: 0.7222 - val_loss: 0.5995 - val_accuracy: 0.7397
# Epoch 7/100
# 1060/1060 [==============================] - 18s 17ms/step - loss: 0.6371 - accuracy: 0.7269 - val_loss: 0.6077 - val_accuracy: 0.7383
# Epoch 8/100
# 1060/1060 [==============================] - 18s 17ms/step - loss: 0.6324 - accuracy: 0.7283 - val_loss: 0.5923 - val_accuracy: 0.7444
# Epoch 9/100
# 1060/1060 [==============================] - 16s 15ms/step - loss: 0.6262 - accuracy: 0.7302 - val_loss: 0.5889 - val_accuracy: 0.7444
# Epoch 10/100
# 1060/1060 [==============================] - 20s 18ms/step - loss: 0.6212 - accuracy: 0.7318 - val_loss: 0.5877 - val_accuracy: 0.7477
# Epoch 11/100
# 1060/1060 [==============================] - 32s 30ms/step - loss: 0.6163 - accuracy: 0.7339 - val_loss: 0.5887 - val_accuracy: 0.7448
# Epoch 12/100
# 1060/1060 [==============================] - 32s 31ms/step - loss: 0.6179 - accuracy: 0.7347 - val_loss: 0.5778 - val_accuracy: 0.7503
# Epoch 13/100
# 1060/1060 [==============================] - 20s 19ms/step - loss: 0.6104 - accuracy: 0.7368 - val_loss: 0.5670 - val_accuracy: 0.7547
# Epoch 14/100
# 1060/1060 [==============================] - 15s 14ms/step - loss: 0.6091 - accuracy: 0.7374 - val_loss: 0.5712 - val_accuracy: 0.7519
# Epoch 15/100
# 1060/1060 [==============================] - 16s 15ms/step - loss: 0.6030 - accuracy: 0.7418 - val_loss: 0.5951 - val_accuracy: 0.7427
# Epoch 16/100
# 1060/1060 [==============================] - 28s 27ms/step - loss: 0.6003 - accuracy: 0.7421 - val_loss: 0.5541 - val_accuracy: 0.7610
# Epoch 17/100
# 1060/1060 [==============================] - 27s 25ms/step - loss: 0.5985 - accuracy: 0.7419 - val_loss: 0.5616 - val_accuracy: 0.7528
# Epoch 18/100
# 1060/1060 [==============================] - 29s 27ms/step - loss: 0.5935 - accuracy: 0.7444 - val_loss: 0.5554 - val_accuracy: 0.7594
# Epoch 19/100
# 1060/1060 [==============================] - 27s 25ms/step - loss: 0.5909 - accuracy: 0.7444 - val_loss: 0.5517 - val_accuracy: 0.7589
# Epoch 20/100
# 1060/1060 [==============================] - 29s 27ms/step - loss: 0.5878 - accuracy: 0.7477 - val_loss: 0.5584 - val_accuracy: 0.7607
# Epoch 21/100
# 1060/1060 [==============================] - 29s 28ms/step - loss: 0.5865 - accuracy: 0.7466 - val_loss: 0.5554 - val_accuracy: 0.7627
# Epoch 22/100
# 1060/1060 [==============================] - 21s 20ms/step - loss: 0.5809 - accuracy: 0.7492 - val_loss: 0.5569 - val_accuracy: 0.7588
# Epoch 23/100
# 1060/1060 [==============================] - 15s 14ms/step - loss: 0.5805 - accuracy: 0.7487 - val_loss: 0.5518 - val_accuracy: 0.7600
# Epoch 24/100
# 1060/1060 [==============================] - 15s 14ms/step - loss: 0.5744 - accuracy: 0.7526 - val_loss: 0.5583 - val_accuracy: 0.7568
# Epoch 25/100
# 1060/1060 [==============================] - 14s 13ms/step - loss: 0.5745 - accuracy: 0.7530 - val_loss: 0.5435 - val_accuracy: 0.7653
# Epoch 26/100
# 1060/1060 [==============================] - 14s 13ms/step - loss: 0.5737 - accuracy: 0.7537 - val_loss: 0.5458 - val_accuracy: 0.7624
# Epoch 27/100
# 1060/1060 [==============================] - 16s 15ms/step - loss: 0.5723 - accuracy: 0.7527 - val_loss: 0.5499 - val_accuracy: 0.7609
# Epoch 28/100
# 1060/1060 [==============================] - 15s 14ms/step - loss: 0.5702 - accuracy: 0.7539 - val_loss: 0.5490 - val_accuracy: 0.7633
# Epoch 29/100
# 1060/1060 [==============================] - 15s 15ms/step - loss: 0.5670 - accuracy: 0.7569 - val_loss: 0.5430 - val_accuracy: 0.7632
# Epoch 30/100
# 1060/1060 [==============================] - 15s 14ms/step - loss: 0.5645 - accuracy: 0.7536 - val_loss: 0.5422 - val_accuracy: 0.7608
# Epoch 31/100
# 1060/1060 [==============================] - 14s 13ms/step - loss: 0.5644 - accuracy: 0.7565 - val_loss: 0.5381 - val_accuracy: 0.7674
# Epoch 32/100
# 1060/1060 [==============================] - 14s 13ms/step - loss: 0.5624 - accuracy: 0.7596 - val_loss: 0.5275 - val_accuracy: 0.7707
# Epoch 33/100
# 1060/1060 [==============================] - 14s 13ms/step - loss: 0.5627 - accuracy: 0.7584 - val_loss: 0.5280 - val_accuracy: 0.7695
# Epoch 34/100
# 1060/1060 [==============================] - 15s 14ms/step - loss: 0.5552 - accuracy: 0.7585 - val_loss: 0.5329 - val_accuracy: 0.7693
# Epoch 35/100
# 1060/1060 [==============================] - 16s 15ms/step - loss: 0.5551 - accuracy: 0.7610 - val_loss: 0.5410 - val_accuracy: 0.7707
# Epoch 36/100
# 1060/1060 [==============================] - 15s 14ms/step - loss: 0.5581 - accuracy: 0.7588 - val_loss: 0.5278 - val_accuracy: 0.7694
# Epoch 37/100
# 1060/1060 [==============================] - 14s 13ms/step - loss: 0.5534 - accuracy: 0.7613 - val_loss: 0.5265 - val_accuracy: 0.7714
# Epoch 38/100
# 1060/1060 [==============================] - 14s 13ms/step - loss: 0.5526 - accuracy: 0.7623 - val_loss: 0.5440 - val_accuracy: 0.7662
# Epoch 39/100
# 1060/1060 [==============================] - 14s 13ms/step - loss: 0.5461 - accuracy: 0.7650 - val_loss: 0.5360 - val_accuracy: 0.7708
# Epoch 40/100
# 1060/1060 [==============================] - 14s 13ms/step - loss: 0.5527 - accuracy: 0.7611 - val_loss: 0.5175 - val_accuracy: 0.7745
# Epoch 41/100
# 1060/1060 [==============================] - 14s 13ms/step - loss: 0.5473 - accuracy: 0.7635 - val_loss: 0.5195 - val_accuracy: 0.7729
# Epoch 42/100
# 1060/1060 [==============================] - 14s 13ms/step - loss: 0.5483 - accuracy: 0.7624 - val_loss: 0.5252 - val_accuracy: 0.7694
# Epoch 43/100
# 1060/1060 [==============================] - 14s 13ms/step - loss: 0.5457 - accuracy: 0.7662 - val_loss: 0.5251 - val_accuracy: 0.7725
# Epoch 44/100
# 1060/1060 [==============================] - 14s 13ms/step - loss: 0.5437 - accuracy: 0.7662 - val_loss: 0.5183 - val_accuracy: 0.7736
# Epoch 45/100
# 1060/1060 [==============================] - 14s 13ms/step - loss: 0.5430 - accuracy: 0.7688 - val_loss: 0.5227 - val_accuracy: 0.7766
# Epoch 46/100
# 1060/1060 [==============================] - 14s 13ms/step - loss: 0.5432 - accuracy: 0.7644 - val_loss: 0.5213 - val_accuracy: 0.7754
# Epoch 47/100
# 1060/1060 [==============================] - 16s 15ms/step - loss: 0.5424 - accuracy: 0.7678 - val_loss: 0.5209 - val_accuracy: 0.7722
# Epoch 48/100
# 1060/1060 [==============================] - 18s 17ms/step - loss: 0.5414 - accuracy: 0.7676 - val_loss: 0.5207 - val_accuracy: 0.7693
# Epoch 49/100
# 1060/1060 [==============================] - 20s 19ms/step - loss: 0.5364 - accuracy: 0.7685 - val_loss: 0.5216 - val_accuracy: 0.7721
# Epoch 50/100
# 1060/1060 [==============================] - 18s 17ms/step - loss: 0.5344 - accuracy: 0.7684 - val_loss: 0.5142 - val_accuracy: 0.7792
# Epoch 51/100
# 1060/1060 [==============================] - 16s 15ms/step - loss: 0.5337 - accuracy: 0.7726 - val_loss: 0.5192 - val_accuracy: 0.7773
# Epoch 52/100
# 1060/1060 [==============================] - 13s 13ms/step - loss: 0.5350 - accuracy: 0.7707 - val_loss: 0.5100 - val_accuracy: 0.7818
# Epoch 53/100
# 1060/1060 [==============================] - 14s 14ms/step - loss: 0.5318 - accuracy: 0.7731 - val_loss: 0.5082 - val_accuracy: 0.7826
# Epoch 54/100
# 1060/1060 [==============================] - 15s 14ms/step - loss: 0.5320 - accuracy: 0.7712 - val_loss: 0.5123 - val_accuracy: 0.7770
# Epoch 55/100
# 1060/1060 [==============================] - 13s 13ms/step - loss: 0.5312 - accuracy: 0.7726 - val_loss: 0.5224 - val_accuracy: 0.7709
# Epoch 56/100
# 1060/1060 [==============================] - 13s 13ms/step - loss: 0.5291 - accuracy: 0.7711 - val_loss: 0.5059 - val_accuracy: 0.7797
# Epoch 57/100
# 1060/1060 [==============================] - 13s 12ms/step - loss: 0.5286 - accuracy: 0.7717 - val_loss: 0.5065 - val_accuracy: 0.7843
# Epoch 58/100
# 1060/1060 [==============================] - 13s 13ms/step - loss: 0.5285 - accuracy: 0.7729 - val_loss: 0.5058 - val_accuracy: 0.7836
# Epoch 59/100
# 1060/1060 [==============================] - 13s 12ms/step - loss: 0.5244 - accuracy: 0.7718 - val_loss: 0.5042 - val_accuracy: 0.7794
# Epoch 60/100
# 1060/1060 [==============================] - 13s 12ms/step - loss: 0.5250 - accuracy: 0.7747 - val_loss: 0.5107 - val_accuracy: 0.7801
# Epoch 61/100
# 1060/1060 [==============================] - 13s 12ms/step - loss: 0.5262 - accuracy: 0.7750 - val_loss: 0.5017 - val_accuracy: 0.7806
# Epoch 62/100
# 1060/1060 [==============================] - 15s 14ms/step - loss: 0.5216 - accuracy: 0.7738 - val_loss: 0.5053 - val_accuracy: 0.7827
# Epoch 63/100
# 1060/1060 [==============================] - 15s 14ms/step - loss: 0.5219 - accuracy: 0.7750 - val_loss: 0.5013 - val_accuracy: 0.7833
# Epoch 64/100
# 1060/1060 [==============================] - 14s 14ms/step - loss: 0.5260 - accuracy: 0.7754 - val_loss: 0.5077 - val_accuracy: 0.7806
# Epoch 65/100
# 1060/1060 [==============================] - 14s 14ms/step - loss: 0.5210 - accuracy: 0.7756 - val_loss: 0.5067 - val_accuracy: 0.7832
# Epoch 66/100
# 1060/1060 [==============================] - 14s 14ms/step - loss: 0.5214 - accuracy: 0.7763 - val_loss: 0.5069 - val_accuracy: 0.7814
# Epoch 67/100
# 1060/1060 [==============================] - 16s 15ms/step - loss: 0.5195 - accuracy: 0.7759 - val_loss: 0.5039 - val_accuracy: 0.7839
# Epoch 68/100
# 1060/1060 [==============================] - 20s 19ms/step - loss: 0.5177 - accuracy: 0.7758 - val_loss: 0.5060 - val_accuracy: 0.7821
# Epoch 69/100
# 1060/1060 [==============================] - 17s 16ms/step - loss: 0.5112 - accuracy: 0.7778 - val_loss: 0.5101 - val_accuracy: 0.7836
# Epoch 70/100
# 1060/1060 [==============================] - 15s 14ms/step - loss: 0.5182 - accuracy: 0.7777 - val_loss: 0.5074 - val_accuracy: 0.7765
# Epoch 71/100
# 1060/1060 [==============================] - 14s 13ms/step - loss: 0.5164 - accuracy: 0.7760 - val_loss: 0.5042 - val_accuracy: 0.7816
# Epoch 72/100
# 1060/1060 [==============================] - 14s 13ms/step - loss: 0.5157 - accuracy: 0.7762 - val_loss: 0.5013 - val_accuracy: 0.7816
# Epoch 73/100
# 1060/1060 [==============================] - 14s 13ms/step - loss: 0.5173 - accuracy: 0.7782 - val_loss: 0.4983 - val_accuracy: 0.7872
# Epoch 74/100
# 1060/1060 [==============================] - 15s 14ms/step - loss: 0.5155 - accuracy: 0.7790 - val_loss: 0.4994 - val_accuracy: 0.7905
# Epoch 75/100
# 1060/1060 [==============================] - 15s 14ms/step - loss: 0.5137 - accuracy: 0.7792 - val_loss: 0.5075 - val_accuracy: 0.7823
# Epoch 76/100
# 1060/1060 [==============================] - 17s 16ms/step - loss: 0.5111 - accuracy: 0.7808 - val_loss: 0.4960 - val_accuracy: 0.7856
# Epoch 77/100
# 1060/1060 [==============================] - 15s 14ms/step - loss: 0.5141 - accuracy: 0.7801 - val_loss: 0.5050 - val_accuracy: 0.7874
# Epoch 78/100
# 1060/1060 [==============================] - 15s 15ms/step - loss: 0.5142 - accuracy: 0.7804 - val_loss: 0.4974 - val_accuracy: 0.7873
# Epoch 79/100
# 1060/1060 [==============================] - 15s 14ms/step - loss: 0.5149 - accuracy: 0.7769 - val_loss: 0.5004 - val_accuracy: 0.7826
# Epoch 80/100
# 1060/1060 [==============================] - 17s 16ms/step - loss: 0.5141 - accuracy: 0.7788 - val_loss: 0.4892 - val_accuracy: 0.7904
# Epoch 81/100
# 1060/1060 [==============================] - 15s 14ms/step - loss: 0.5106 - accuracy: 0.7813 - val_loss: 0.4922 - val_accuracy: 0.7898
# Epoch 82/100
# 1060/1060 [==============================] - 15s 14ms/step - loss: 0.5083 - accuracy: 0.7814 - val_loss: 0.4976 - val_accuracy: 0.7872
# Epoch 83/100
# 1060/1060 [==============================] - 15s 15ms/step - loss: 0.5073 - accuracy: 0.7805 - val_loss: 0.4992 - val_accuracy: 0.7853
# Epoch 84/100
# 1060/1060 [==============================] - 16s 15ms/step - loss: 0.5020 - accuracy: 0.7853 - val_loss: 0.4892 - val_accuracy: 0.7904
# Epoch 85/100
# 1060/1060 [==============================] - 15s 14ms/step - loss: 0.5041 - accuracy: 0.7834 - val_loss: 0.4982 - val_accuracy: 0.7883
# Epoch 86/100
# 1060/1060 [==============================] - 13s 13ms/step - loss: 0.5088 - accuracy: 0.7813 - val_loss: 0.4970 - val_accuracy: 0.7827
# Epoch 87/100
# 1060/1060 [==============================] - 13s 12ms/step - loss: 0.5068 - accuracy: 0.7804 - val_loss: 0.4925 - val_accuracy: 0.7882
# Epoch 88/100
# 1060/1060 [==============================] - 13s 12ms/step - loss: 0.5072 - accuracy: 0.7799 - val_loss: 0.4902 - val_accuracy: 0.7863
# Epoch 89/100
# 1060/1060 [==============================] - 13s 12ms/step - loss: 0.5088 - accuracy: 0.7824 - val_loss: 0.5007 - val_accuracy: 0.7913
# Epoch 90/100
# 1060/1060 [==============================] - 13s 12ms/step - loss: 0.5027 - accuracy: 0.7843 - val_loss: 0.4913 - val_accuracy: 0.7854
# Epoch 91/100
# 1060/1060 [==============================] - 13s 12ms/step - loss: 0.5039 - accuracy: 0.7807 - val_loss: 0.4989 - val_accuracy: 0.7820
# Epoch 92/100
# 1060/1060 [==============================] - 13s 12ms/step - loss: 0.5040 - accuracy: 0.7849 - val_loss: 0.4829 - val_accuracy: 0.7917
# Epoch 93/100
# 1060/1060 [==============================] - 13s 12ms/step - loss: 0.5030 - accuracy: 0.7825 - val_loss: 0.4861 - val_accuracy: 0.7930
# Epoch 94/100
# 1060/1060 [==============================] - 13s 12ms/step - loss: 0.5032 - accuracy: 0.7828 - val_loss: 0.4877 - val_accuracy: 0.7869
# Epoch 95/100
# 1060/1060 [==============================] - 13s 12ms/step - loss: 0.5044 - accuracy: 0.7844 - val_loss: 0.4870 - val_accuracy: 0.7923
# Epoch 96/100
# 1060/1060 [==============================] - 13s 12ms/step - loss: 0.5003 - accuracy: 0.7842 - val_loss: 0.4931 - val_accuracy: 0.7856
# Epoch 97/100
# 1060/1060 [==============================] - 13s 12ms/step - loss: 0.5001 - accuracy: 0.7832 - val_loss: 0.4869 - val_accuracy: 0.7895
# Epoch 98/100
# 1060/1060 [==============================] - 13s 12ms/step - loss: 0.4984 - accuracy: 0.7830 - val_loss: 0.4958 - val_accuracy: 0.7845
# Epoch 99/100
# 1060/1060 [==============================] - 13s 12ms/step - loss: 0.5004 - accuracy: 0.7848 - val_loss: 0.4914 - val_accuracy: 0.7876
# Epoch 100/100
# 1060/1060 [==============================] - 15s 14ms/step - loss: 0.4992 - accuracy: 0.7848 - val_loss: 0.4862 - val_accuracy: 0.7917

# %%
_, model_accuracy = model.evaluate(X_test, y_test, verbose=0)
print("Model Accuraccy: ", round(model_accuracy, 2))
summarize_loss(history)
# Out:
# Model Accuraccy:  0.79

# %%
y_pred = model.predict(X_test)
y_pred = y_pred > 0.5
print('\n\t\tECG - CNN V1 - MODEL EVALUATION\n')
print(classification_report(y_test, y_pred, target_names=['SR', 'AFIB', 'OTHER']))
plot_conf_matrix(y_test, y_pred)
# Out:
# 		ECG - CNN V1 - MODEL EVALUATION
#
#               precision    recall  f1-score   support
#
#           SR       0.71      0.84      0.77      3292
#         AFIB       0.86      0.91      0.88      3839
#        OTHER       0.86      0.55      0.67      3467
#
#    micro avg       0.80      0.77      0.78     10598
#    macro avg       0.81      0.76      0.77     10598
# weighted avg       0.81      0.77      0.78     10598
#  samples avg       0.77      0.77      0.77     10598
# c:\python38\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
