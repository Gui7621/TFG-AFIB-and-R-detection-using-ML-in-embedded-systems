# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import wfdb
import ast

# %%
def load_raw_data(df, sampling_rate, path):
    '''
    função para carregar os dados originais
    '''
    if sampling_rate == 100:
        data = [wfdb.rdsamp(path+f) for f in df.filename_lr]
    else:
        data = [wfdb.rdsamp(path+f) for f in df.filename_hr]
    data = np.array([signal for signal, meta in data])
    return data

# %%
ls
# Out:
#  O volume na unidade C ‚ Acer
#  O N£mero de S‚rie do Volume ‚ EC13-D8A4
#
#  Pasta de C:\Users\GUILH\Downloads\ptb-xl-a-large-publicly-available-electrocardiography-dataset-1.0.1\ptb-xl-a-large-publicly-available-electrocardiography-dataset-1.0.1
#
# 02/04/2021  17:34    <DIR>          .
# 02/04/2021  17:34    <DIR>          ..
# 31/03/2021  15:47    <DIR>          .ipynb_checkpoints
# 23/04/2020  10:21             1.340 example_physionet.py
# 24/04/2020  10:42            14.842 LICENSE.txt
# 23/04/2020  10:21         6.602.796 ptbxl_database.csv
# 23/04/2020  10:21         1.135.522 RECORDS
# 29/03/2021  23:11    <DIR>          records100
# 29/03/2021  23:19    <DIR>          records500
# 23/04/2020  10:21             9.720 scp_statements.csv
# 24/04/2020  14:08         8.298.464 SHA256SUMS.txt
# 02/04/2021  17:34             6.820 Untitled.ipynb
#                7 arquivo(s)     16.069.504 bytes
#                5 pasta(s)   406.370.004.992 bytes dispon¡veis

# %%
path = ''
sampling_rate=100

# %%
# load and convert annotation data
Y = pd.read_csv(path+'ptbxl_database.csv', index_col='ecg_id')
Y.shape
# Out:
# (21837, 27)

# %%
Y.head(10)
# Out:
#         patient_id   age  sex  height  weight  nurse  site     device  \
# ecg_id
# 1          15709.0  56.0    1     NaN    63.0    2.0   0.0  CS-12   E
# 2          13243.0  19.0    0     NaN    70.0    2.0   0.0  CS-12   E
# 3          20372.0  37.0    1     NaN    69.0    2.0   0.0  CS-12   E
# 4          17014.0  24.0    0     NaN    82.0    2.0   0.0  CS-12   E
# 5          17448.0  19.0    1     NaN    70.0    2.0   0.0  CS-12   E
# 6          19005.0  18.0    1     NaN    58.0    2.0   0.0  CS-12   E
# 7          16193.0  54.0    0     NaN    83.0    2.0   0.0  CS-12   E
# 8          11275.0  48.0    0     NaN    95.0    2.0   0.0  CS-12   E
# 9          18792.0  55.0    0     NaN    70.0    2.0   0.0  CS-12   E
# 10          9456.0  22.0    1     NaN    56.0    2.0   0.0  CS-12   E
#
#              recording_date  \
# ecg_id
# 1       1984-11-09 09:17:34
# 2       1984-11-14 12:55:37
# 3       1984-11-15 12:49:10
# 4       1984-11-15 13:44:57
# 5       1984-11-17 10:43:15
# ...

# %%
Y.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21837 entries, 1 to 21837
# Data columns (total 27 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   patient_id                    21837 non-null  float64
#  1   age                           21748 non-null  float64
#  2   sex                           21837 non-null  int64
#  3   height                        6983 non-null   float64
#  4   weight                        9429 non-null   float64
#  5   nurse                         20328 non-null  float64
#  6   site                          21819 non-null  float64
#  7   device                        21837 non-null  object
#  8   recording_date                21837 non-null  object
#  9   report                        21837 non-null  object
#  10  scp_codes                     21837 non-null  object
#  11  heart_axis                    13332 non-null  object
# ...

# %%
Y.describe()
# Out:
#          patient_id           age           sex       height       weight  \
# count  21837.000000  21748.000000  21837.000000  6983.000000  9429.000000
# mean   11255.005953     59.836307      0.478912   166.708292    70.997561
# std     6234.132489     16.953125      0.499567    10.864935    15.875146
# min      302.000000      2.000000      0.000000     6.000000     5.000000
# 25%     5982.000000     50.000000      0.000000   160.000000    60.000000
# 50%    11423.000000     62.000000      0.000000   166.000000    70.000000
# 75%    16614.000000     72.000000      1.000000   174.000000    80.000000
# max    21797.000000     95.000000      1.000000   209.000000   250.000000
#
#               nurse          site  validated_by    strat_fold
# count  20328.000000  21819.000000  12426.000000  21837.000000
# mean       2.292503      1.547229      0.747948      5.505335
# std        3.254786      4.169753      1.183269      2.875306
# ...

# %%
Y.scp_codes = Y.scp_codes.apply(lambda x: ast.literal_eval(x))

# %%
# Load raw signal data
X = load_raw_data(Y, sampling_rate, path)

# %%
dt_I = X[:,:,0]

# %%
dt_I.shape
# Out:
# (21837, 1000)

# %%
plt.plot(dt_I[0], label="Lead I")

# %%
 plt.rcParams["figure.figsize"] = (20,10)

# %%
plt.plot(dt_I[0], label="Lead I")

# %%
plt.rcParams["figure.figsize"] = (15,10)

# %%
plt.plot(dt_I[0], label="Lead I")

# %%
for i in range (5):
    plt.plot(dt_I[i], label="Lead I")
    plt.title("Lead I for sample: "+str(i))
    plt.show()

# %%
# Load scp_statements.csv for diagnostic aggregation
agg_df = pd.read_csv(path+'scp_statements.csv', index_col=0)

# %%
agg_df.shape
# Out:
# (71, 12)

# %%
agg_df.head()
# Out:
#                           description  diagnostic  form  rhythm  \
# NDT    non-diagnostic T abnormalities         1.0   1.0     NaN
# NST_          non-specific ST changes         1.0   1.0     NaN
# DIG                  digitalis-effect         1.0   1.0     NaN
# LNGQT                long QT-interval         1.0   1.0     NaN
# NORM                       normal ECG         1.0   NaN     NaN
#
#       diagnostic_class diagnostic_subclass  \
# NDT               STTC                STTC
# NST_              STTC                NST_
# DIG               STTC                STTC
# LNGQT             STTC                STTC
# NORM              NORM                NORM
#
#                                       Statement Category  \
# NDT                    other ST-T descriptive statements
# NST_   Basic roots for coding ST-T changes and abnorm...
# DIG                    other ST-T descriptive statements
# LNGQT                  other ST-T descriptive statements
# ...

# %%
def aggregate_rhythm(y_dic):
    tmp = []
    for key in y_dic.keys():
        if key in agg_df.index:
            tmp.append(agg_df.loc[key].rhythm)
    return list(set(tmp))

# %%
agg_df_x = pd.read_csv(path+'scp_statements.csv', index_col=0)
agg_df_x.shape
# Out:
# (71, 12)

# %%
agg_df_I = agg_df_x[agg_df_x.rhythm == 1]
agg_df_I.shape
# Out:
# (12, 12)

# %%
agg_df_I
# Out:
#                                              description  diagnostic  form  \
# SR                                          sinus rhythm         NaN   NaN
# AFIB                                 atrial fibrillation         NaN   NaN
# STACH                                  sinus tachycardia         NaN   NaN
# SARRH                                   sinus arrhythmia         NaN   NaN
# SBRAD                                  sinus bradycardia         NaN   NaN
# PACE             normal functioning artificial pacemaker         NaN   NaN
# SVARR                        supraventricular arrhythmia         NaN   NaN
# BIGU   bigeminal pattern (unknown origin, SV or Ventr...         NaN   NaN
# AFLT                                      atrial flutter         NaN   NaN
# SVTAC                       supraventricular tachycardia         NaN   NaN
# PSVT             paroxysmal supraventricular tachycardia         NaN   NaN
# ...

# %%
def aggregate_rhythm(y_dic):
    tmp = []
    for key in y_dic.keys():
        if key in agg_df_x.index:
            tmp.append(agg_df_x.loc[key].rhythm)
    return list(set(tmp))

# %%
YI = Y.copy()

# %%
YI.head()
# Out:
#         patient_id   age  sex  height  weight  nurse  site     device  \
# ecg_id
# 1          15709.0  56.0    1     NaN    63.0    2.0   0.0  CS-12   E
# 2          13243.0  19.0    0     NaN    70.0    2.0   0.0  CS-12   E
# 3          20372.0  37.0    1     NaN    69.0    2.0   0.0  CS-12   E
# 4          17014.0  24.0    0     NaN    82.0    2.0   0.0  CS-12   E
# 5          17448.0  19.0    1     NaN    70.0    2.0   0.0  CS-12   E
#
#              recording_date                                  report  ...  \
# ecg_id                                                               ...
# 1       1984-11-09 09:17:34  sinusrhythmus periphere niederspannung  ...
# 2       1984-11-14 12:55:37     sinusbradykardie sonst normales ekg  ...
# 3       1984-11-15 12:49:10              sinusrhythmus normales ekg  ...
# 4       1984-11-15 13:44:57              sinusrhythmus normales ekg  ...
# 5       1984-11-17 10:43:15              sinusrhythmus normales ekg  ...
#
# ...

# %%
YI['rhythm_class'] = Y.scp_codes.apply(aggregate_rhythm)

# %%
YI['rhythm_class'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [1.0]                   366
# [nan, 1.0]                1
# [nan, 1.0]                1
# [nan, 1.0]                1
# [nan, 1.0]                1
#                        ...
# [nan, 1.0]                1
# [nan, nan, 1.0]           1
# [nan, 1.0]                1
# [nan, nan, nan, 1.0]      1
# [nan, nan, 1.0]           1
# Name: rhythm_class, Length: 21472, dtype: int64

# %%
YI.head()
# Out:
#         patient_id   age  sex  height  weight  nurse  site     device  \
# ecg_id
# 1          15709.0  56.0    1     NaN    63.0    2.0   0.0  CS-12   E
# 2          13243.0  19.0    0     NaN    70.0    2.0   0.0  CS-12   E
# 3          20372.0  37.0    1     NaN    69.0    2.0   0.0  CS-12   E
# 4          17014.0  24.0    0     NaN    82.0    2.0   0.0  CS-12   E
# 5          17448.0  19.0    1     NaN    70.0    2.0   0.0  CS-12   E
#
#              recording_date                                  report  ...  \
# ecg_id                                                               ...
# 1       1984-11-09 09:17:34  sinusrhythmus periphere niederspannung  ...
# 2       1984-11-14 12:55:37     sinusbradykardie sonst normales ekg  ...
# 3       1984-11-15 12:49:10              sinusrhythmus normales ekg  ...
# 4       1984-11-15 13:44:57              sinusrhythmus normales ekg  ...
# 5       1984-11-17 10:43:15              sinusrhythmus normales ekg  ...
#
# ...

# %%
def aggregate_diagnostic(y_dic):
    tmp = []
    for key in y_dic.keys():
        if key in agg_df.index:
            tmp.append(agg_df.loc[key].diagnostic_class)
    return list(set(tmp))

# %%
agg_df = pd.read_csv(path+'scp_statements.csv', index_col=0)
agg_df = agg_df[agg_df.diagnostic == 1]

# %%
Y['diagnostic_superclass'] = Y.scp_codes.apply(aggregate_diagnostic)

# %%
Y.head(10)
# Out:
#         patient_id   age  sex  height  weight  nurse  site     device  \
# ecg_id
# 1          15709.0  56.0    1     NaN    63.0    2.0   0.0  CS-12   E
# 2          13243.0  19.0    0     NaN    70.0    2.0   0.0  CS-12   E
# 3          20372.0  37.0    1     NaN    69.0    2.0   0.0  CS-12   E
# 4          17014.0  24.0    0     NaN    82.0    2.0   0.0  CS-12   E
# 5          17448.0  19.0    1     NaN    70.0    2.0   0.0  CS-12   E
# 6          19005.0  18.0    1     NaN    58.0    2.0   0.0  CS-12   E
# 7          16193.0  54.0    0     NaN    83.0    2.0   0.0  CS-12   E
# 8          11275.0  48.0    0     NaN    95.0    2.0   0.0  CS-12   E
# 9          18792.0  55.0    0     NaN    70.0    2.0   0.0  CS-12   E
# 10          9456.0  22.0    1     NaN    56.0    2.0   0.0  CS-12   E
#
#              recording_date  \
# ecg_id
# 1       1984-11-09 09:17:34
# 2       1984-11-14 12:55:37
# 3       1984-11-15 12:49:10
# 4       1984-11-15 13:44:57
# 5       1984-11-17 10:43:15
# ...

# %%
agg_df
# Out:
#                                                description  diagnostic  form  \
# NDT                         non-diagnostic T abnormalities         1.0   1.0
# NST_                               non-specific ST changes         1.0   1.0
# DIG                                       digitalis-effect         1.0   1.0
# LNGQT                                     long QT-interval         1.0   1.0
# NORM                                            normal ECG         1.0   NaN
# IMI                         inferior myocardial infarction         1.0   NaN
# ASMI                    anteroseptal myocardial infarction         1.0   NaN
# LVH                           left ventricular hypertrophy         1.0   NaN
# LAFB                        left anterior fascicular block         1.0   NaN
# ISC_                                 non-specific ischemic         1.0   NaN
# IRBBB                 incomplete right bundle branch block         1.0   NaN
# ...

# %%
agg_df_I
# Out:
#                                              description  diagnostic  form  \
# SR                                          sinus rhythm         NaN   NaN
# AFIB                                 atrial fibrillation         NaN   NaN
# STACH                                  sinus tachycardia         NaN   NaN
# SARRH                                   sinus arrhythmia         NaN   NaN
# SBRAD                                  sinus bradycardia         NaN   NaN
# PACE             normal functioning artificial pacemaker         NaN   NaN
# SVARR                        supraventricular arrhythmia         NaN   NaN
# BIGU   bigeminal pattern (unknown origin, SV or Ventr...         NaN   NaN
# AFLT                                      atrial flutter         NaN   NaN
# SVTAC                       supraventricular tachycardia         NaN   NaN
# PSVT             paroxysmal supraventricular tachycardia         NaN   NaN
# ...

# %%
del YI['rhythm_class']

# %%
def aggregate_rhythm(y_dic):
    tmp = []
    for key in y_dic.keys():
        if key in agg_df_I.index:
            tmp.append(agg_df_I.loc[key].rhythm)
    return list(set(tmp))

# %%
YR = Y.copy()

# %%
YR.head()
# Out:
#         patient_id   age  sex  height  weight  nurse  site     device  \
# ecg_id
# 1          15709.0  56.0    1     NaN    63.0    2.0   0.0  CS-12   E
# 2          13243.0  19.0    0     NaN    70.0    2.0   0.0  CS-12   E
# 3          20372.0  37.0    1     NaN    69.0    2.0   0.0  CS-12   E
# 4          17014.0  24.0    0     NaN    82.0    2.0   0.0  CS-12   E
# 5          17448.0  19.0    1     NaN    70.0    2.0   0.0  CS-12   E
#
#              recording_date                                  report  ...  \
# ecg_id                                                               ...
# 1       1984-11-09 09:17:34  sinusrhythmus periphere niederspannung  ...
# 2       1984-11-14 12:55:37     sinusbradykardie sonst normales ekg  ...
# 3       1984-11-15 12:49:10              sinusrhythmus normales ekg  ...
# 4       1984-11-15 13:44:57              sinusrhythmus normales ekg  ...
# 5       1984-11-17 10:43:15              sinusrhythmus normales ekg  ...
#
# ...

# %%
YR['rhythm_class'] = Y.scp_codes.apply(aggregate_rhythm)

# %%
YR.head()
# Out:
#         patient_id   age  sex  height  weight  nurse  site     device  \
# ecg_id
# 1          15709.0  56.0    1     NaN    63.0    2.0   0.0  CS-12   E
# 2          13243.0  19.0    0     NaN    70.0    2.0   0.0  CS-12   E
# 3          20372.0  37.0    1     NaN    69.0    2.0   0.0  CS-12   E
# 4          17014.0  24.0    0     NaN    82.0    2.0   0.0  CS-12   E
# 5          17448.0  19.0    1     NaN    70.0    2.0   0.0  CS-12   E
#
#              recording_date                                  report  ...  \
# ecg_id                                                               ...
# 1       1984-11-09 09:17:34  sinusrhythmus periphere niederspannung  ...
# 2       1984-11-14 12:55:37     sinusbradykardie sonst normales ekg  ...
# 3       1984-11-15 12:49:10              sinusrhythmus normales ekg  ...
# 4       1984-11-15 13:44:57              sinusrhythmus normales ekg  ...
# 5       1984-11-17 10:43:15              sinusrhythmus normales ekg  ...
#
# ...

# %%
YR['rhythm_class'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [1.0]    21066
# []         771
# Name: rhythm_class, dtype: int64

# %%
wfdb.rdsamp()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-641579d63aab> in <module>
# ----> 1 wfdb.rdsamp()
#
# TypeError: rdsamp() missing 1 required positional argument: 'record_name'

# %%
load_raw_data()

# %%
def load_raw_data(df, sampling_rate, path):
    '''
    função para carregar os dados originais
    '''
    if sampling_rate == 100:
        data = [wfdb.rdsamp(path+f) for f in df.filename_lr]
    else:
        data = [wfdb.rdsamp(path+f) for f in df.filename_hr]
    data = np.array([signal for signal, meta in data])
    return data

# %%
ls

# %%
path = ''
sampling_rate=100

# %%
# load and convert annotation data
Y = pd.read_csv(path+'ptbxl_database.csv', index_col='ecg_id')
Y.shape

# %%
Y.head(10)

# %%
Y.info()

# %%
Y.describe()

# %%
Y.scp_codes = Y.scp_codes.apply(lambda x: ast.literal_eval(x))

# %%
# Load raw signal data
X = load_raw_data(Y, sampling_rate, path)

# %%
dt_I = X[:,:,0]

# %%
dt_I.shape

# %%
plt.plot(dt_I[0], label="Lead I")

# %%
# Load scp_statements.csv for diagnostic aggregation
agg_df = pd.read_csv(path+'scp_statements.csv', index_col=0)

# %%
agg_df.shape

# %%
agg_df.head()

# %%
agg_df = agg_df[agg_df.diagnostic == 1]

# %%
def aggregate_diagnostic(y_dic):
    tmp = []
    for key in y_dic.keys():
        if key in agg_df.index:
            tmp.append(agg_df.loc[key].diagnostic_class)
    return list(set(tmp))

# %%
# Apply diagnostic superclass
Y['diagnostic_superclass'] = Y.scp_codes.apply(aggregate_diagnostic)

# %%
Y['diagnostic_superclass'].value_counts()

# %%
# Split data into train and test
test_fold = 10
# Train
X_train = X[np.where(Y.strat_fold != test_fold)]
y_train = Y[(Y.strat_fold != test_fold)].diagnostic_superclass
# Test
X_test = X[np.where(Y.strat_fold == test_fold)]
y_test = Y[Y.strat_fold == test_fold].diagnostic_superclass
